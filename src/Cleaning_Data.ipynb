# %%
# !pip install import-ipynb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting import-ipynb
#   Downloading import_ipynb-0.1.4-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from import-ipynb) (5.4.0)
# Requirement already satisfied: IPython in /usr/local/lib/python3.7/dist-packages (from import-ipynb) (5.5.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (57.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (1.0.18)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (2.6.1)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (0.8.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (4.8.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->IPython->import-ipynb) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->IPython->import-ipynb) (0.2.5)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->import-ipynb) (4.3.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat->import-ipynb) (4.11.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->import-ipynb) (2.16.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (5.9.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (4.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (21.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (4.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->import-ipynb) (3.8.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->IPython->import-ipynb) (0.7.0)
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.4

# %%
# importing the tools to call google drive
from google.colab import drive
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import import_ipynb
import pickle as pkl

# %%
# mount our directory
mount='/content/gdrive'
drive.mount(mount, force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# Switch to the directory on the VM for our purposes
drive_root=mount + '/My Drive/Colab Notebooks/Thesis'
# %cd $drive_root
# %pwd
# Out:
# /content/gdrive/My Drive/Colab Notebooks/Thesis
# '/content/gdrive/My Drive/Colab Notebooks/Thesis'

# %%
import Pitch_Plot
import data
from data import obtain_seasons,fetch_url,Game
from Pitch_Plot import pitchplot
# Out:
# importing Jupyter notebook from Pitch_Plot.ipynb
# importing Jupyter notebook from data.ipynb

# %%
laliga = obtain_seasons(11)
# Out:
# Getting season 2020/2021...
# Getting season 2019/2020...
# Getting season 2018/2019...
# Getting season 2017/2018...
# Getting season 2016/2017...
# Getting season 2015/2016...
# Getting season 2014/2015...
# Getting season 2013/2014...
# Getting season 2012/2013...
# Getting season 2011/2012...
# Getting season 2010/2011...
# Getting season 2009/2010...
# Getting season 2008/2009...
# Getting season 2007/2008...
# Getting season 2006/2007...
# Getting season 2005/2006...
# Getting season 2004/2005...
# Done

# %%
laliga
# Out:
# {'2004/2005': {'68313': <data.Game at 0x7feb1095d5d0>,
#   '68314': <data.Game at 0x7feb10f11a50>,
#   '68315': <data.Game at 0x7feb0fee9e10>,
#   '68316': <data.Game at 0x7feb0f4b8990>,
#   '68352': <data.Game at 0x7feb0e900f10>,
#   '68353': <data.Game at 0x7feb0c78cd10>,
#   '69153': <data.Game at 0x7feb0dda0c10>},
#  '2005/2006': {'68317': <data.Game at 0x7feb17671e50>,
#   '68318': <data.Game at 0x7feb12671510>,
#   '68319': <data.Game at 0x7feb13d00f90>,
#   '68320': <data.Game at 0x7feb1d1e6ed0>,
#   '68321': <data.Game at 0x7feb149f7f50>,
#   '68322': <data.Game at 0x7feb13c86990>,
#   '68323': <data.Game at 0x7feb1af5cc10>,
#   '68324': <data.Game at 0x7feb1c685d50>,
#   '68325': <data.Game at 0x7feb182fd450>,
#   '68339': <data.Game at 0x7feb198b3e10>,
#   '68342': <data.Game at 0x7feb130b3910>,
#   '68348': <data.Game at 0x7feb1a336590>,
#   '68350': <data.Game at 0x7feb16035d50>,
#   '68351': <data.Game at 0x7feb18c06550>,
#   '68354': <data.Game at 0x7feb182f6c10>,
#   '69164': <data.Game at 0x7feb1dd96c10>,
#   '69172': <data.Game at 0x7feb1a328f50>},
#  '2006/2007': {'68326': <data.Game at 0x7feb2f154b10>,
#   '68327': <data.Game at 0x7feb1f495e50>,
#   '68328': <data.Game at 0x7feb327bd3d0>,
#   '68329': <data.Game at 0x7feb2a836150>,
#   '68330': <data.Game at 0x7feb2a836850>,
#   '68331': <data.Game at 0x7feb22e95710>,
#   '68332': <data.Game at 0x7feb2b55fd10>,
#   '68333': <data.Game at 0x7feb2fd7ee90>,
#   '68334': <data.Game at 0x7feb31599810>,
#   '68335': <data.Game at 0x7feb2d931750>,
#   '68336': <data.Game at 0x7feb2e4cec10>,
#   '68340': <data.Game at 0x7feb21683c10>,
#   '68341': <data.Game at 0x7feb29029c10>,
#   '68347': <data.Game at 0x7feb20bacf90>,
#   '69154': <data.Game at 0x7feb269da710>,
#   '69155': <data.Game at 0x7feb2818e950>,
#   '69156': <data.Game at 0x7feb27679d10>,
#   '69157': <data.Game at 0x7feb20034890>,
#   '69159': <data.Game at 0x7feb25ea2d90>,
#   '69160': <data.Game at 0x7feb269dab10>,
#   '69162': <data.Game at 0x7feb2cce9fd0>,
#   '69165': <data.Game at 0x7feb29cec390>,
#   '69174': <data.Game at 0x7fecb1616490>,
#   '69175': <data.Game at 0x7feb24684950>,
#   '69176': <data.Game at 0x7feb327bd890>,
#   '69179': <data.Game at 0x7feb30a72bd0>},
#  '2007/2008': {'68356': <data.Game at 0x7feb3e690dd0>,
#   '68358': <data.Game at 0x7feb37055ad0>,
#   '68359': <data.Game at 0x7feb400f6210>,
#   '68360': <data.Game at 0x7feb46349bd0>,
#   '68361': <data.Game at 0x7feb34dfe8d0>,
#   '68363': <data.Game at 0x7feb3b91fdd0>,
#   '68364': <data.Game at 0x7feb40bf7f90>,
#   '68365': <data.Game at 0x7feb417afc50>,
#   '68366': <data.Game at 0x7feb3a05d810>,
#   '69141': <data.Game at 0x7feb34226dd0>,
#   '69143': <data.Game at 0x7feb456b3e10>,
#   '69144': <data.Game at 0x7feb46fe7c90>,
#   '69145': <data.Game at 0x7feb364ec890>,
#   '69146': <data.Game at 0x7feb38916c90>,
#   '69148': <data.Game at 0x7feb3ac48c90>,
#   '69151': <data.Game at 0x7feb48e61a50>,
#   '69158': <data.Game at 0x7feb3cfc9f10>,
#   '69166': <data.Game at 0x7feb3c413e90>,
#   '69169': <data.Game at 0x7feb46353310>,
#   '69170': <data.Game at 0x7feb3f3d6950>,
#   '69173': <data.Game at 0x7feb37ce3750>,
#   '69178': <data.Game at 0x7feb430fa850>,
#   '69180': <data.Game at 0x7feb43c9de10>,
#   '69181': <data.Game at 0x7feb456b3ad0>,
#   '69182': <data.Game at 0x7feb364e3dd0>,
#   '69184': <data.Game at 0x7feb39432050>,
#   '69186': <data.Game at 0x7feb449aafd0>,
#   '69187': <data.Game at 0x7feb3daded90>},
#  '2008/2009': {'69138': <data.Game at 0x7feb4e2a7d90>,
#   '69139': <data.Game at 0x7feb528c70d0>,
#   '69142': <data.Game at 0x7feb54a2c050>,
#   '69147': <data.Game at 0x7feb59d46910>,
#   '69149': <data.Game at 0x7feb79510d50>,
#   '69171': <data.Game at 0x7feb506d6cd0>,
#   '69177': <data.Game at 0x7feb4cb1bed0>,
#   '69183': <data.Game at 0x7feb94713cd0>,
#   '69185': <data.Game at 0x7feb53499e10>,
#   '69189': <data.Game at 0x7feb51235f50>,
#   '69195': <data.Game at 0x7feb556a1d10>,
#   '69207': <data.Game at 0x7feb4be87d50>,
#   '69209': <data.Game at 0x7feb59d4cc90>,
#   '69211': <data.Game at 0x7feb93b971d0>,
#   '69212': <data.Game at 0x7feb5bf34fd0>,
#   '69215': <data.Game at 0x7feb5123ea10>,
#   '69216': <data.Game at 0x7feb59dbee50>,
#   '69217': <data.Game at 0x7feb57978f90>,
#   '69222': <data.Game at 0x7feb561c7c50>,
#   '69223': <data.Game at 0x7feb56d34490>,
#   '69225': <data.Game at 0x7feb5dd99810>,
#   '69228': <data.Game at 0x7feb4b2fbed0>,
#   '69230': <data.Game at 0x7feb4a784e10>,
#   '69231': <data.Game at 0x7feb585a2fd0>,
#   '69232': <data.Game at 0x7feb5a9bac50>,
#   '69235': <data.Game at 0x7feb5ca57f90>,
#   '69249': <data.Game at 0x7feb51c48210>,
#   '69251': <data.Game at 0x7feb53f4ce10>,
#   '69273': <data.Game at 0x7feb591e9310>,
#   '69279': <data.Game at 0x7feb9471a210>,
#   '69285': <data.Game at 0x7feb7a0d3810>},
#  '2009/2010': {'69210': <data.Game at 0x7feb6d898ed0>,
#   '69213': <data.Game at 0x7feb65a7a190>,
#   '69214': <data.Game at 0x7fecb2dfd450>,
#   '69218': <data.Game at 0x7feb72124e10>,
#   '69219': <data.Game at 0x7feb744934d0>,
#   '69220': <data.Game at 0x7feb6bf76cd0>,
#   '69221': <data.Game at 0x7feb5ed07c90>,
#   '69224': <data.Game at 0x7feb70a1a510>,
#   '69226': <data.Game at 0x7feb6b198f90>,
#   '69227': <data.Game at 0x7feb62ae1d10>,
#   '69229': <data.Game at 0x7feb738db910>,
#   '69233': <data.Game at 0x7feb673f2790>,
#   '69237': <data.Game at 0x7feb6cbc9d10>,
#   '69238': <data.Game at 0x7feb642d0f10>,
#   '69239': <data.Game at 0x7feb791ccd10>,
#   '69240': <data.Game at 0x7feb66700c10>,
#   '69241': <data.Game at 0x7feb784c3dd0>,
#   '69242': <data.Game at 0x7feb70a14cd0>,
#   '69243': <data.Game at 0x7feb7a999d50>,
#   '69244': <data.Game at 0x7feb7522be50>,
#   '69247': <data.Game at 0x7feb5fa21c10>,
#   '69250': <data.Game at 0x7feb714d6a50>,
#   '69252': <data.Game at 0x7feb697d6790>,
#   '69253': <data.Game at 0x7feb7606af90>,
#   '69254': <data.Game at 0x7feb61fbff50>,
#   '69255': <data.Game at 0x7feb68b81f50>,
#   '69256': <data.Game at 0x7feb7212e710>,
#   '69257': <data.Game at 0x7feb77800910>,
#   '69259': <data.Game at 0x7feb6e52ee90>,
#   '69262': <data.Game at 0x7febe7998e90>,
#   '69267': <data.Game at 0x7feb64dffed0>,
#   '69277': <data.Game at 0x7feb752337d0>,
#   '69288': <data.Game at 0x7feb636796d0>,
#   '69292': <data.Game at 0x7feb6126bcd0>,
#   '69298': <data.Game at 0x7feb6fe80d50>},
#  '2010/2011': {'69234': <data.Game at 0x7feb83ae4ed0>,
#   '69236': <data.Game at 0x7feb82dbd890>,
#   '69245': <data.Game at 0x7feb8daa18d0>,
#   '69246': <data.Game at 0x7feb89a59b10>,
#   '69248': <data.Game at 0x7feb7c3d97d0>,
#   '69260': <data.Game at 0x7febcff72110>,
#   '69263': <data.Game at 0x7feb7d07ffd0>,
#   '69269': <data.Game at 0x7febcff72ed0>,
#   '69270': <data.Game at 0x7feb8cb6de50>,
#   '69271': <data.Game at 0x7feb92922e50>,
#   '69272': <data.Game at 0x7feb813cfe10>,
#   '69274': <data.Game at 0x7feb88e03dd0>,
#   '69275': <data.Game at 0x7feb9023ca10>,
#   '69276': <data.Game at 0x7feb94e2fa10>,
#   '69278': <data.Game at 0x7feb8f569e50>,
#   '69280': <data.Game at 0x7feb85633f50>,
#   '69282': <data.Game at 0x7feb87f61dd0>,
#   '69283': <data.Game at 0x7feb87108190>,
#   '69286': <data.Game at 0x7feb8643d0d0>,
#   '69287': <data.Game at 0x7feb8b1376d0>,
#   '69289': <data.Game at 0x7feb813d5650>,
#   '69291': <data.Game at 0x7feb8474bc10>,
#   '69295': <data.Game at 0x7feb8e727bd0>,
#   '69296': <data.Game at 0x7febb4ff1fd0>,
#   '69299': <data.Game at 0x7feb7f76df50>,
#   '69300': <data.Game at 0x7feb804de710>,
#   '69302': <data.Game at 0x7feb8a682f90>,
#   '69303': <data.Game at 0x7feb8f574690>,
#   '69304': <data.Game at 0x7feb937507d0>,
#   '69305': <data.Game at 0x7feb90e79890>,
#   '69306': <data.Game at 0x7feb7dbe9a10>,
#   '69307': <data.Game at 0x7feb91b7b8d0>,
#   '69308': <data.Game at 0x7feb821e6910>},
#  '2011/2012': {'69264': <data.Game at 0x7feba5783c90>,
#   '69265': <data.Game at 0x7feba2f5cfd0>,
#   '69268': <data.Game at 0x7feba9964250>,
#   '69293': <data.Game at 0x7feba9964950>,
#   '69297': <data.Game at 0x7febab557a90>,
#   '69312': <data.Game at 0x7feb9c454d10>,
#   '69314': <data.Game at 0x7feb9a9f5a50>,
#   '69315': <data.Game at 0x7feba13d3d10>,
#   '69316': <data.Game at 0x7febaf92a610>,
#   '69318': <data.Game at 0x7feb99caff50>,
#   '69319': <data.Game at 0x7feba3d378d0>,
#   '69320': <data.Game at 0x7feb9ebb0ad0>,
#   '69322': <data.Game at 0x7febb1e7be10>,
#   '69323': <data.Game at 0x7feb9691c910>,
#   '69324': <data.Game at 0x7febaa63a6d0>,
#   '69325': <data.Game at 0x7febac1c2450>,
#   '69326': <data.Game at 0x7feb9dfaea50>,
#   '69327': <data.Game at 0x7feba0661950>,
#   '69328': <data.Game at 0x7febb529a290>,
#   '69329': <data.Game at 0x7febb43a2710>,
#   '69330': <data.Game at 0x7febad0eced0>,
#   '69331': <data.Game at 0x7febb12e4fd0>,
#   '69332': <data.Game at 0x7febb12ed850>,
#   '69333': <data.Game at 0x7feba64a4d10>,
#   '69334': <data.Game at 0x7feba213cd10>,
#   '69335': <data.Game at 0x7febaf92d950>,
#   '69336': <data.Game at 0x7feb9f8a5b50>,
#   '69337': <data.Game at 0x7febb06bcf50>,
#   '69338': <data.Game at 0x7feb99cafed0>,
#   '69340': <data.Game at 0x7feba498f990>,
#   '69343': <data.Game at 0x7feba714dad0>,
#   '70219': <data.Game at 0x7febb2c0ebd0>,
#   '70220': <data.Game at 0x7feb98ecba10>,
#   '70221': <data.Game at 0x7feb981e7d10>,
#   '70223': <data.Game at 0x7feba71c0dd0>,
#   '70224': <data.Game at 0x7feb97537b50>,
#   '70225': <data.Game at 0x7feba8d03f90>},
#  '2012/2013': {'266015': <data.Game at 0x7febd20da890>,
#   '266433': <data.Game at 0x7febc5875fd0>,
#   '266724': <data.Game at 0x7febcca8ecd0>,
#   '266827': <data.Game at 0x7febba3a0a50>,
#   '267502': <data.Game at 0x7febb9444dd0>,
#   '70256': <data.Game at 0x7febc7448790>,
#   '70259': <data.Game at 0x7febc4a10fd0>,
#   '70260': <data.Game at 0x7febc31bbd90>,
#   '70262': <data.Game at 0x7febb6a62190>,
#   '70263': <data.Game at 0x7febc24ab910>,
#   '70270': <data.Game at 0x7febce5f0e10>,
#   '70271': <data.Game at 0x7febb868df90>,
#   '70272': <data.Game at 0x7febcad04f90>,
#   '70275': <data.Game at 0x7febc0915e50>,
#   '70276': <data.Game at 0x7febc15f3dd0>,
#   '70280': <data.Game at 0x7febc839a7d0>,
#   '70281': <data.Game at 0x7febcf4134d0>,
#   '70282': <data.Game at 0x7febcbbb3c10>,
#   '70284': <data.Game at 0x7febbfcadf50>,
#   '70286': <data.Game at 0x7febc587e310>,
#   '70287': <data.Game at 0x7febc0915f50>,
#   '70292': <data.Game at 0x7febb5edec90>,
#   '70294': <data.Game at 0x7febb7838e10>,
#   '70295': <data.Game at 0x7febbce3bd50>,
#   '70296': <data.Game at 0x7febc839ad10>,
#   '70297': <data.Game at 0x7febc66b1d10>,
#   '70300': <data.Game at 0x7febcd8759d0>,
#   '70304': <data.Game at 0x7febc9188bd0>,
#   '70305': <data.Game at 0x7febbb364b50>,
#   '70307': <data.Game at 0x7febbc118f90>,
#   '70308': <data.Game at 0x7febcd875fd0>,
#   '70309': <data.Game at 0x7febe7854910>},
#  '2013/2014': {'265830': <data.Game at 0x7febd7b05790>,
#   '265837': <data.Game at 0x7febd46f2550>,
#   '265857': <data.Game at 0x7febd6043ad0>,
#   '265918': <data.Game at 0x7febdd466150>,
#   '266066': <data.Game at 0x7febe47dc790>,
#   '266074': <data.Game at 0x7febe06a5e90>,
#   '266201': <data.Game at 0x7febdf998f90>,
#   '266256': <data.Game at 0x7febda1a3a90>,
#   '266274': <data.Game at 0x7febde217ad0>,
#   '266420': <data.Game at 0x7febd20dae50>,
#   '266462': <data.Game at 0x7febd2e57790>,
#   '266491': <data.Game at 0x7febd9445810>,
#   '266603': <data.Game at 0x7febd6ddfe10>,
#   '266613': <data.Game at 0x7febd88e7e90>,
#   '266883': <data.Game at 0x7febd5354bd0>,
#   '267138': <data.Game at 0x7febe6c25950>,
#   '267192': <data.Game at 0x7febd3a2a550>,
#   '267368': <data.Game at 0x7febe798f9d0>,
#   '267520': <data.Game at 0x7febe538f5d0>,
#   '267567': <data.Game at 0x7febe2ce6ed0>,
#   '267675': <data.Game at 0x7febe2ce63d0>,
#   '70277': <data.Game at 0x7febdd45ab50>,
#   '70283': <data.Game at 0x7febdaeb7c50>,
#   '70288': <data.Game at 0x7febe1248fd0>,
#   '70289': <data.Game at 0x7febe39fff50>,
#   '70291': <data.Game at 0x7febe6046dd0>,
#   '70293': <data.Game at 0x7febdd45ab90>,
#   '70298': <data.Game at 0x7fec05e8c750>,
#   '70301': <data.Game at 0x7fec20861f10>,
#   '70302': <data.Game at 0x7fec06be0850>,
#   '70306': <data.Game at 0x7febdbaa2210>},
#  '2014/2015': {'265835': <data.Game at 0x7fec07591790>,
#   '265866': <data.Game at 0x7fec0024a350>,
#   '265896': <data.Game at 0x7febff582e10>,
#   '265963': <data.Game at 0x7fec05cec710>,
#   '266045': <data.Game at 0x7febf906a750>,
#   '266117': <data.Game at 0x7fec043e3150>,
#   '266142': <data.Game at 0x7febe86ebe50>,
#   '266148': <data.Game at 0x7febfb5b8c50>,
#   '266230': <data.Game at 0x7febf222bfd0>,
#   '266240': <data.Game at 0x7febf839ac10>,
#   '266320': <data.Game at 0x7febf3cb0690>,
#   '266406': <data.Game at 0x7febfc16dd10>,
#   '266525': <data.Game at 0x7febf3029d50>,
#   '266531': <data.Game at 0x7febeecdadd0>,
#   '266560': <data.Game at 0x7febf14d4fd0>,
#   '266631': <data.Game at 0x7febf3cb0d90>,
#   '266741': <data.Game at 0x7febec6caf10>,
#   '266770': <data.Game at 0x7febeadf9d10>,
#   '266794': <data.Game at 0x7febf528ab50>,
#   '266838': <data.Game at 0x7fec04f2add0>,
#   '266846': <data.Game at 0x7febefa8e910>,
#   '266871': <data.Game at 0x7febee01b110>,
#   '266916': <data.Game at 0x7fec02a01dd0>,
#   '266921': <data.Game at 0x7febee00fed0>,
#   '266929': <data.Game at 0x7febea07ef90>,
#   '266967': <data.Game at 0x7febebac3550>,
#   '267085': <data.Game at 0x7febfa896fd0>,
#   '267183': <data.Game at 0x7fec0368d9d0>,
#   '267197': <data.Game at 0x7fec01d8fb10>,
#   '267301': <data.Game at 0x7febfe7b9f90>,
#   '267343': <data.Game at 0x7febf46b5850>,
#   '267400': <data.Game at 0x7febfdb5cd90>,
#   '267499': <data.Game at 0x7febf0792290>,
#   '267561': <data.Game at 0x7febf9b9afd0>,
#   '267597': <data.Game at 0x7febf6bc3950>,
#   '70264': <data.Game at 0x7fec002c1f50>,
#   '70273': <data.Game at 0x7febff57cfd0>,
#   '70303': <data.Game at 0x7febf778acd0>},
#  '2015/2016': {'265839': <data.Game at 0x7fec0c353c90>,
#   '265894': <data.Game at 0x7fec1ac8a4d0>,
#   '265944': <data.Game at 0x7fec1c4685d0>,
#   '265958': <data.Game at 0x7fec19575f10>,
#   '266056': <data.Game at 0x7fec0f782cd0>,
#   '266106': <data.Game at 0x7fec13213dd0>,
#   '266149': <data.Game at 0x7fec1030ac90>,
#   '266160': <data.Game at 0x7fec17e31050>,
#   '266166': <data.Game at 0x7fec0e9d7cd0>,
#   '266236': <data.Game at 0x7fec18a30e50>,
#   '266254': <data.Game at 0x7fec0a87ad50>,
#   '266310': <data.Game at 0x7fec1d1fabd0>,
#   '266424': <data.Game at 0x7fec0c11e750>,
#   '266467': <data.Game at 0x7fec1a0631d0>,
#   '266490': <data.Game at 0x7fec09ab2b10>,
#   '266498': <data.Game at 0x7fec39b81850>,
#   '266557': <data.Game at 0x7fec08de8710>,
#   '266620': <data.Game at 0x7fecafd7dd90>,
#   '266653': <data.Game at 0x7fec1d201410>,
#   '266664': <data.Game at 0x7fec1271ac50>,
#   '266670': <data.Game at 0x7fec11b34bd0>,
#   '266815': <data.Game at 0x7fec13ed0e90>,
#   '266885': <data.Game at 0x7fec16583910>,
#   '266961': <data.Game at 0x7fec158bff50>,
#   '266986': <data.Game at 0x7fec1eaf2c90>,
#   '267273': <data.Game at 0x7fec0b43ef10>,
#   '267274': <data.Game at 0x7fec165f9bd0>,
#   '267327': <data.Game at 0x7fec0dc87ed0>,
#   '267422': <data.Game at 0x7fec17e2dbd0>,
#   '267506': <data.Game at 0x7fecafd7df50>,
#   '267533': <data.Game at 0x7fec1de77c90>,
#   '267576': <data.Game at 0x7fec1de7ea10>,
#   '267611': <data.Game at 0x7fec19504c10>},
#  '2016/2017': {'265952': <data.Game at 0x7fec23ec5fd0>,
#   '266033': <data.Game at 0x7fec312ca350>,
#   '266191': <data.Game at 0x7fec258279d0>,
#   '266273': <data.Game at 0x7fec2e12ee50>,
#   '266280': <data.Game at 0x7fec35d19ed0>,
#   '266299': <data.Game at 0x7fec26285cd0>,
#   '266357': <data.Game at 0x7fec38ea7f50>,
#   '266440': <data.Game at 0x7fec305fbad0>,
#   '266477': <data.Game at 0x7fec337dff10>,
#   '266516': <data.Game at 0x7fec35173590>,
#   '266528': <data.Game at 0x7fec3b1f9290>,
#   '266669': <data.Game at 0x7fec3690df90>,
#   '266731': <data.Game at 0x7fec2bc82b50>,
#   '266874': <data.Game at 0x7fec2d45a9d0>,
#   '266892': <data.Game at 0x7fec38116d10>,
#   '266952': <data.Game at 0x7fec270c2d50>,
#   '266989': <data.Game at 0x7fec3ca86bd0>,
#   '267039': <data.Game at 0x7fec32c709d0>,
#   '267058': <data.Game at 0x7fec232d5690>,
#   '267076': <data.Game at 0x7fec57b54bd0>,
#   '267077': <data.Game at 0x7fec746fc650>,
#   '267101': <data.Game at 0x7fec3133fb90>,
#   '267212': <data.Game at 0x7fec37497f90>,
#   '267220': <data.Game at 0x7fec35d21110>,
#   '267373': <data.Game at 0x7fec28a34610>,
#   '267395': <data.Game at 0x7fec2f9e7050>,
#   '267432': <data.Game at 0x7fec2a42d0d0>,
#   '267464': <data.Game at 0x7fec28a34e10>,
#   '267492': <data.Game at 0x7fec23ed1a90>,
#   '267569': <data.Game at 0x7fec3a1ac250>,
#   '267590': <data.Game at 0x7fec746fc790>,
#   '267596': <data.Game at 0x7fec22645750>,
#   '267660': <data.Game at 0x7fec2eda3a10>,
#   '267670': <data.Game at 0x7fec343c9dd0>},
#  '2017/2018': {'9575': <data.Game at 0x7fec5686b710>,
#   '9581': <data.Game at 0x7fec3e585d50>,
#   '9592': <data.Game at 0x7fec4e4b1fd0>,
#   '9602': <data.Game at 0x7fec40a10c50>,
#   '9609': <data.Game at 0x7fec575c7e90>,
#   '9620': <data.Game at 0x7fec46233ed0>,
#   '9636': <data.Game at 0x7fec74c6a9d0>,
#   '9642': <data.Game at 0x7fec423a8b50>,
#   '9650': <data.Game at 0x7fec48bb7110>,
#   '9661': <data.Game at 0x7fec4f0a8f10>,
#   '9673': <data.Game at 0x7fec47da9e90>,
#   '9682': <data.Game at 0x7fec3fe32f10>,
#   '9695': <data.Game at 0x7fec4cb4c0d0>,
#   '9700': <data.Game at 0x7fec4c0ffcd0>,
#   '9717': <data.Game at 0x7fec74327f10>,
#   '9726': <data.Game at 0x7fec3d85fe50>,
#   '9736': <data.Game at 0x7fec55c01b50>,
#   '9742': <data.Game at 0x7fec5405d710>,
#   '9754': <data.Game at 0x7fec3f1acd10>,
#   '9765': <data.Game at 0x7fec53298890>,
#   '9774': <data.Game at 0x7fec4302cd50>,
#   '9783': <data.Game at 0x7fec4cb44c90>,
#   '9794': <data.Game at 0x7fec4981cf90>,
#   '9799': <data.Game at 0x7fec58518690>,
#   '9811': <data.Game at 0x7fec45656610>,
#   '9827': <data.Game at 0x7fec4564d790>,
#   '9837': <data.Game at 0x7fec44af2c50>,
#   '9855': <data.Game at 0x7fec5261a950>,
#   '9860': <data.Game at 0x7fec4d878110>,
#   '9870': <data.Game at 0x7fecbc7372d0>,
#   '9880': <data.Game at 0x7fec50beedd0>,
#   '9889': <data.Game at 0x7fec3ca860d0>,
#   '9912': <data.Game at 0x7fec4564dd10>,
#   '9924': <data.Game at 0x7fec51892690>,
#   '9928': <data.Game at 0x7fec54e08d90>,
#   '9948': <data.Game at 0x7fec4166fa50>},
#  '2018/2019': {'15946': <data.Game at 0x7fec6a5d5ed0>,
#   '15956': <data.Game at 0x7fec5d58d910>,
#   '15973': <data.Game at 0x7fec6753a810>,
#   '15978': <data.Game at 0x7fec5c900cd0>,
#   '15986': <data.Game at 0x7fec5fe4b850>,
#   '15998': <data.Game at 0x7fec74e84c10>,
#   '16010': <data.Game at 0x7fec5efd8850>,
#   '16023': <data.Game at 0x7fec5d58dd10>,
#   '16029': <data.Game at 0x7fec7389c110>,
#   '16056': <data.Game at 0x7fec6818ee10>,
#   '16073': <data.Game at 0x7fec71f0aad0>,
#   '16079': <data.Game at 0x7fec66807b10>,
#   '16086': <data.Game at 0x7fec72b4ed10>,
#   '16095': <data.Game at 0x7fec60b09710>,
#   '16109': <data.Game at 0x7fec6f79a8d0>,
#   '16120': <data.Game at 0x7fec6e987fd0>,
#   '16131': <data.Game at 0x7fec6264b8d0>,
#   '16136': <data.Game at 0x7fec6a5d5d10>,
#   '16149': <data.Game at 0x7fec659ddd90>,
#   '16157': <data.Game at 0x7fec6ce15250>,
#   '16173': <data.Game at 0x7fec6c096dd0>,
#   '16182': <data.Game at 0x7fec70406790>,
#   '16190': <data.Game at 0x7fec711a5e90>,
#   '16196': <data.Game at 0x7fec5ba99e90>,
#   '16205': <data.Game at 0x7fec633aef90>,
#   '16215': <data.Game at 0x7fec6ce0ee10>,
#   '16231': <data.Game at 0x7fec591c9dd0>,
#   '16240': <data.Game at 0x7fec5e376c10>,
#   '16248': <data.Game at 0x7fec8f9fcf90>,
#   '16265': <data.Game at 0x7fec6b3bae50>,
#   '16275': <data.Game at 0x7fec64cdbfd0>,
#   '16289': <data.Game at 0x7fec67532d10>,
#   '16306': <data.Game at 0x7fec618e2f90>,
#   '16317': <data.Game at 0x7fec6405af90>},
#  '2019/2020': {'303377': <data.Game at 0x7fec7a8ff610>,
#   '303400': <data.Game at 0x7fec896ff9d0>,
#   '303421': <data.Game at 0x7fec86107dd0>,
#   '303430': <data.Game at 0x7fecada6d250>,
#   '303451': <data.Game at 0x7fecae2d5890>,
#   '303470': <data.Game at 0x7fec7dd64490>,
#   '303473': <data.Game at 0x7fec75b55f90>,
#   '303479': <data.Game at 0x7fec853f8a10>,
#   '303487': <data.Game at 0x7fec81292f90>,
#   '303493': <data.Game at 0x7fec86e2b610>,
#   '303504': <data.Game at 0x7fecada468d0>,
#   '303516': <data.Game at 0x7fec8de6a590>,
#   '303517': <data.Game at 0x7fec790c4d50>,
#   '303524': <data.Game at 0x7fec7855eed0>,
#   '303532': <data.Game at 0x7fec8de62c10>,
#   '303548': <data.Game at 0x7fec80565990>,
#   '303596': <data.Game at 0x7fecada6d2d0>,
#   '303600': <data.Game at 0x7fec82c7e990>,
#   '303610': <data.Game at 0x7fec76ac3d50>,
#   '303615': <data.Game at 0x7fec82c76cd0>,
#   '303634': <data.Game at 0x7fec87b91e90>,
#   '303652': <data.Game at 0x7fec7eaa3e90>,
#   '303664': <data.Game at 0x7fec8a501950>,
#   '303666': <data.Game at 0x7fec7cf8c3d0>,
#   '303674': <data.Game at 0x7fec7dd5dfd0>,
#   '303680': <data.Game at 0x7fec8465de10>,
#   '303682': <data.Game at 0x7fec8895ea90>,
#   '303696': <data.Game at 0x7fec81faafd0>,
#   '303700': <data.Game at 0x7fec7c19ab10>,
#   '303707': <data.Game at 0x7fec7cf86e90>,
#   '303715': <data.Game at 0x7fec79d53950>,
#   '303725': <data.Game at 0x7fec8bfe6890>,
#   '303731': <data.Game at 0x7fec90005d90>},
#  '2020/2021': {'3764440': <data.Game at 0x7fec935ecd10>,
#   '3764661': <data.Game at 0x7fec9bca7790>,
#   '3773369': <data.Game at 0x7fecafa86250>,
#   '3773372': <data.Game at 0x7fecad6f43d0>,
#   '3773377': <data.Game at 0x7feca841dd90>,
#   '3773386': <data.Game at 0x7feca776afd0>,
#   '3773387': <data.Game at 0x7fecad7a1ad0>,
#   '3773403': <data.Game at 0x7fec95db2990>,
#   '3773415': <data.Game at 0x7fec95dc2650>,
#   '3773428': <data.Game at 0x7fec99344d50>,
#   '3773457': <data.Game at 0x7fecada7e7d0>,
#   '3773466': <data.Game at 0x7feca3608950>,
#   '3773474': <data.Game at 0x7fec96b28a10>,
#   '3773477': <data.Game at 0x7fec91a65d90>,
#   '3773497': <data.Game at 0x7fec9ca62590>,
#   '3773523': <data.Game at 0x7fec9d69bfd0>,
#   '3773526': <data.Game at 0x7fec98615590>,
#   '3773547': <data.Game at 0x7fec94391850>,
#   '3773552': <data.Game at 0x7feca1b95f90>,
#   '3773565': <data.Game at 0x7feca6914f90>,
#   '3773571': <data.Game at 0x7fec9e40ba10>,
#   '3773585': <data.Game at 0x7feca4f3c610>,
#   '3773586': <data.Game at 0x7feca9fb0850>,
#   '3773587': <data.Game at 0x7feca4f3cc50>,
#   '3773593': <data.Game at 0x7feca0dc0c10>,
#   '3773597': <data.Game at 0x7fec9e405dd0>,
#   '3773625': <data.Game at 0x7fec95db2c90>,
#   '3773631': <data.Game at 0x7fec9d6a2a90>,
#   '3773656': <data.Game at 0x7feca9203250>,
#   '3773660': <data.Game at 0x7fec9fef7dd0>,
#   '3773661': <data.Game at 0x7fec9f1d1f90>,
#   '3773665': <data.Game at 0x7fec9a1a4510>,
#   '3773672': <data.Game at 0x7feca447bdd0>,
#   '3773689': <data.Game at 0x7fec91a65e10>,
#   '3773695': <data.Game at 0x7fecad6ef090>}}

# %%
for events in laliga["2020/2021"]['3764661'].json_file:
  if events['type']['name'] == 'Shot':
    print(events['id'],events['shot']['outcome']['name'],events['player']['name'])
# Out:
# b813fffa-b444-4a3f-8586-2de114316973 Goal Iñaki Williams Arthuer
# c9011163-1aab-4bc6-8118-c8d28df7cb68 Off T Yuri Berchiche Izeta
# 32364c05-6f18-479b-90f7-29cfbd75c24a Saved Sergino Dest
# 3f673426-4e8c-4fdd-9bbb-1e3f1f27b2f6 Blocked Iker Muniain Goñi
# 5155fc31-5d45-48cd-9002-d88310123eee Saved Iñaki Williams Arthuer
# 7cd59690-adb1-4b18-9657-9b40b5c3006c Saved Ousmane Dembélé
# 47f0a963-8801-4ff2-9be5-006163dba91d Goal Pedro González López
# b701fa3a-0ef5-4b77-8ad2-f2b0e705f1df Saved Jordi Alba Ramos
# b3a60617-c4ad-40d8-9791-19d54a088984 Saved Ousmane Dembélé
# 1d9a647b-7207-4425-881c-ac532115239a Goal Lionel Andrés Messi Cuccittini
# 1bdf0330-5e4b-4ba1-8987-7497f60d2a07 Saved Antoine Griezmann
# cc004d38-ee9c-446b-aa74-fa8f9e08f84a Off T Lionel Andrés Messi Cuccittini
# 791664a8-b7fd-4a0e-86a5-9728207c575c Saved Unai Vencedor Paris
# a17b9644-4ebc-4739-a65a-5a1ab72a7146 Off T Raúl García Escudero
# 04b9c00f-1b79-4864-aefd-b549def94215 Post Lionel Andrés Messi Cuccittini
# 56b8ec6e-4cea-47bc-bf2c-df16aef732b6 Goal Lionel Andrés Messi Cuccittini
# e576946a-0590-452f-a09f-ce6584843fce Post Lionel Andrés Messi Cuccittini
# 63e9dea3-872f-42c1-91d7-0cd69a44c0e8 Off T Antoine Griezmann
# 89ef0753-825f-444d-bf19-697601949a26 Saved Antoine Griezmann
# 5de3cb92-93f5-4396-93ab-b65f0165def6 Off T Alejandro Berenguer Remiro
# dee523d8-6866-4890-a25b-5083b74bd610 Goal Iker Muniain Goñi

# %%
pitchplot()
goalkeeper_x = 120
goalkeeper_y = 40
player_list_x = []
player_list_y = []
player_name = []
team_name = []
location_of_shot_x = 0
location_of_shot_y = 0
shot_end_location_x = 0
shot_end_location_y = 0
teammate_x = []
teammate_y = []
for events in laliga["2020/2021"]['3764661'].json_file:
    if events['id'] == "1d9a647b-7207-4425-881c-ac532115239a":
        location_of_shot_x = events['location'][0]
        location_of_shot_y = events['location'][1]
        shot_end_location_x = events['shot']['end_location'][0]
        shot_end_location_y = events['shot']['end_location'][1]
        
        if "freeze_frame" in events["shot"]:
            for players in events['shot']['freeze_frame']:
                player_name.append(events['player']['name'])
                if (players['teammate'] == False):
                    player_list_x.append(players['location'][0])
                    player_list_y.append(players['location'][1])
                    team_name.append(events['possession_team']['name'])
                elif (players['teammate'] == True):
                    teammate_x.append(players['location'][0])
                    teammate_y.append(players['location'][1])
                if ((players['position']['name'] == 'Goalkeeper') and (players['teammate'] == False)):
                    goalkeeper_x = players['location'][0]
                    goalkeeper_y = players['location'][1]   
                   
plt.scatter(player_list_x, player_list_y, color = 'black')
plt.scatter(teammate_x, teammate_y, color = 'brown')
plt.scatter(location_of_shot_x, location_of_shot_y, s=200)
plt.scatter(goalkeeper_x, goalkeeper_y, s=100, color='red')
plt.scatter(shot_end_location_x, shot_end_location_y, s=100, color='green')
plt.plot([location_of_shot_x, 120], [location_of_shot_y,36], color = 'red', linestyle = 'dashed')
plt.plot([location_of_shot_x, 120], [location_of_shot_y,44], color = 'red', linestyle = 'dashed')
plt.title(player_name[0] + '\n' + team_name[0], fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Lionel Andrés Messi Cuccittini\nBarcelona')

# %%
def player_density(x_shot, y_shot, x_player, y_player):
    x_difference = x_player - x_shot
    y_difference = y_player - y_shot
    
    if 120 - x_shot == 0:
        return False
    
    slope_1 = (36 - y_shot) / (120 - x_shot)
    slope_2 = (44 - y_shot) / (120 - x_shot) 
                    
    return (x_difference >= 0) and ((y_shot + slope_1 * x_difference) < y_player < (y_shot + slope_2 * x_difference))

# %%
def pass_type(id, match):
  """
    This function takes the id of the goal assist and returns which type of pass it is.
    
    Arguments:
    id: id of the goal assist
    match: details of the match file   
  """
  key_pass_type = ''
  for events in match:
    if events['id'] == id:
      key_pass_type = events['pass']['height']['name']
      break
  return key_pass_type

# %%
key_pass = []
key_pass_type = []
for events in laliga["2020/2021"]['3764661'].json_file:
  if events['type']['name'] == 'Shot':
    try:
      key_pass.append(events['shot']['key_pass_id'])
      key_pass_type.append(pass_type(events['shot']['key_pass_id'], laliga["2020/2021"]['3764661'].json_file))
    except KeyError:
      key_pass.append('No Pass')
      key_pass_type.append('None')

# %%
key_pass_type
# Out:
# ['Low Pass',
#  'Ground Pass',
#  'Ground Pass',
#  'High Pass',
#  'Ground Pass',
#  'Ground Pass',
#  'High Pass',
#  'Ground Pass',
#  'Ground Pass',
#  'Ground Pass',
#  'Ground Pass',
#  'Low Pass',
#  'None',
#  'None',
#  'Ground Pass',
#  'Ground Pass',
#  'Ground Pass',
#  'None',
#  'Low Pass',
#  'Low Pass',
#  'Ground Pass']

# %%
def obtain_shots_match(match):
    """
    Function which parses through a game json file and returna a data frame containing all shots taken in that game with several features 
    related to that shot
    
    Arguments
    game_json - details of the json file
    """
    
    #features for each shot, which will be the columns of our data frame
    shot_id_list = []
    x_start_location_list = []
    y_start_location_list = []
    play_pattern_list = []
    duration_list = []
    outcome_list = []
    technique_list = []
    type_shot_list = []
    first_time_list = []
    body_part_name = []
    x_gk_pos_list = []
    y_gk_pos_list = []
    num_opponents_5_yards_list = []
    num_opponents_between_goal_list = []
    statsbomb_xg = [] 
    team_name = []
    player_name = []
    key_pass_id = []
    key_pass_type = []
    #-------------------------#

    for events in match:
    
        if events['type']['name'] == 'Shot':
    
            #get data immediately needed features
            shot_id = events['id']
            x_start_location = events['location'][0]
            y_start_location = events['location'][1]
            play_pattern = events['play_pattern']['name']
            duration = events['duration']
            outcome = events['shot']['outcome']['name'] 
            technique = events['shot']['technique']['name']
            type_shot = events['shot']['type']['name']
            xg = events['shot']['statsbomb_xg']
            body_part = events['shot']['body_part']['name']
            team = events['possession_team']['name']
            player1 = events['player']['name']
            pass_id = ''
            type_pass = ''

            try:
                pass_id = events['shot']['key_pass_id']
                type_pass = pass_type(pass_id,match)

            except KeyError:
                pass_id = 'No Pass'
                type_pass = 'None'

            #check if json shot has a first_time attribute, if not set first_time to False
            if 'first_time' in events['shot']:
                first_time = events['shot']['first_time']

            else:
                first_time = False
            
            #check if shot has a freeze_frame dictionary
            if "freeze_frame" in events["shot"]:
                
                num_opponents_5_yards = 0
                num_opponents_between_goal = 0
                
                for player in events["shot"]["freeze_frame"]:
                    x_player = player['location'][0]
                    y_player = player['location'][1]
                    
                    #count how many opponents were within 5 yards of player when shot was taken
                    if ((x_start_location - x_player)**2 + (y_start_location - y_player)**2) <= 25 and (player['teammate'] == False):
                        if (player['position']['name'] != 'Goalkeeper'):
                            num_opponents_5_yards += 1
                    
                    #count how many opponents were between shot and goal
                    if (player['teammate'] == False):
                        if player_density(x_start_location, y_start_location, x_player, y_player):
                            num_opponents_between_goal += 1
                    
                    #get position of opponent's goalkeeper 
                    if ((player['position']['name'] == 'Goalkeeper') and (player['teammate'] == False)):
                        x_gk_pos = player['location'][0]
                        y_gk_pos = player['location'][1]
            
            #if there is no freeze frame, assume goalkeeper is at center of goal, and 0 opponenets around shot location
            else:
                num_opponents_between_goal = 0
                num_opponents_5_yards = 0
                x_gk_pos = 120
                y_gk_pos = 40            
            
            try:
                x_gk_pos_list.append(x_gk_pos)
                y_gk_pos_list.append(y_gk_pos)

            except UnboundLocalError:
                x_gk_pos_list.append(np.nan)
                y_gk_pos_list.append(np.nan)
            
            
            #append data on shot to relevant list (column)
            shot_id_list.append(shot_id)
            play_pattern_list.append(play_pattern)
            x_start_location_list.append(x_start_location)
            y_start_location_list.append(y_start_location)
            duration_list.append(duration)
            outcome_list.append(outcome)
            technique_list.append(technique)
            first_time_list.append(first_time)
            type_shot_list.append(type_shot)
            body_part_name.append(body_part)
            num_opponents_5_yards_list.append(num_opponents_5_yards)
            num_opponents_between_goal_list.append(num_opponents_between_goal)
            statsbomb_xg.append(xg)
            team_name.append(team)
            player_name.append(player1)
            key_pass_id.append(pass_id)
            key_pass_type.append(type_pass)

    #create a data frame with the features
    shot_df = pd.DataFrame({
                       "shot id" : shot_id_list,
                       "play pattern" : play_pattern_list, 
                       "x location shot" : x_start_location_list, 
                       "y location shot" : y_start_location_list,
                       "duration" : duration_list, 
                       "outcome" : outcome_list, 
                       "technique used" : technique_list, 
                       "first time" : first_time_list,
                       "x gk location" : x_gk_pos_list,
                       "y gk location" : y_gk_pos_list,
                       "body part" : body_part_name,
                       "type of shot" : type_shot_list,
                       "Number of opponents in 5 yards" : num_opponents_5_yards_list,
                       "Players between goal" : num_opponents_between_goal_list,
                       "player name" : player_name,
                       "Team Name" : team_name,
                       "official xg" : statsbomb_xg,
                       "Pass id": key_pass_id,
                       "Pass Type": key_pass_type
                       })
    
    return shot_df

# %%
def obtain_season_shots(season):
    """
    Takes a dictionary whichs maps game ids to Game objects, and calls obtain_shots_match() on each one.
    
    Arguments:
    season: dictionary which has game file names (string, as specified by statsbomb) to objects (defined above)
    """
    total_shot_df = pd.DataFrame()
    
    for keys, values in season.items():
        shot_df = obtain_shots_match(values.json_file)
        shot_df["game_id"] = keys
        total_shot_df = total_shot_df.append(shot_df)
        
    return total_shot_df


def obtain_all_shots(league):
    """
    Takes the original data from statsbomb and passes it to obtain_season_shots to process and procure football shots.
    
    Arguments:
    league - The dictionary that iterates season names to a further dictionary. The latter iterates 
    match ids (as defined by statsbomb) to all events in the matches.
    """
    total_shot_df = pd.DataFrame()
    
    for keys, values in league.items():
        shot_df = obtain_season_shots(values)
        shot_df["season_id"] = keys
        total_shot_df = total_shot_df.append(shot_df)
        print("Obtaining shots for " + keys)
    
    print("Done.")
    
    return total_shot_df

# %%
laliga
# Out:
# {'2004/2005': {'68313': <data.Game at 0x7feb1095d5d0>,
#   '68314': <data.Game at 0x7feb10f11a50>,
#   '68315': <data.Game at 0x7feb0fee9e10>,
#   '68316': <data.Game at 0x7feb0f4b8990>,
#   '68352': <data.Game at 0x7feb0e900f10>,
#   '68353': <data.Game at 0x7feb0c78cd10>,
#   '69153': <data.Game at 0x7feb0dda0c10>},
#  '2005/2006': {'68317': <data.Game at 0x7feb17671e50>,
#   '68318': <data.Game at 0x7feb12671510>,
#   '68319': <data.Game at 0x7feb13d00f90>,
#   '68320': <data.Game at 0x7feb1d1e6ed0>,
#   '68321': <data.Game at 0x7feb149f7f50>,
#   '68322': <data.Game at 0x7feb13c86990>,
#   '68323': <data.Game at 0x7feb1af5cc10>,
#   '68324': <data.Game at 0x7feb1c685d50>,
#   '68325': <data.Game at 0x7feb182fd450>,
#   '68339': <data.Game at 0x7feb198b3e10>,
#   '68342': <data.Game at 0x7feb130b3910>,
#   '68348': <data.Game at 0x7feb1a336590>,
#   '68350': <data.Game at 0x7feb16035d50>,
#   '68351': <data.Game at 0x7feb18c06550>,
#   '68354': <data.Game at 0x7feb182f6c10>,
#   '69164': <data.Game at 0x7feb1dd96c10>,
#   '69172': <data.Game at 0x7feb1a328f50>},
#  '2006/2007': {'68326': <data.Game at 0x7feb2f154b10>,
#   '68327': <data.Game at 0x7feb1f495e50>,
#   '68328': <data.Game at 0x7feb327bd3d0>,
#   '68329': <data.Game at 0x7feb2a836150>,
#   '68330': <data.Game at 0x7feb2a836850>,
#   '68331': <data.Game at 0x7feb22e95710>,
#   '68332': <data.Game at 0x7feb2b55fd10>,
#   '68333': <data.Game at 0x7feb2fd7ee90>,
#   '68334': <data.Game at 0x7feb31599810>,
#   '68335': <data.Game at 0x7feb2d931750>,
#   '68336': <data.Game at 0x7feb2e4cec10>,
#   '68340': <data.Game at 0x7feb21683c10>,
#   '68341': <data.Game at 0x7feb29029c10>,
#   '68347': <data.Game at 0x7feb20bacf90>,
#   '69154': <data.Game at 0x7feb269da710>,
#   '69155': <data.Game at 0x7feb2818e950>,
#   '69156': <data.Game at 0x7feb27679d10>,
#   '69157': <data.Game at 0x7feb20034890>,
#   '69159': <data.Game at 0x7feb25ea2d90>,
#   '69160': <data.Game at 0x7feb269dab10>,
#   '69162': <data.Game at 0x7feb2cce9fd0>,
#   '69165': <data.Game at 0x7feb29cec390>,
#   '69174': <data.Game at 0x7fecb1616490>,
#   '69175': <data.Game at 0x7feb24684950>,
#   '69176': <data.Game at 0x7feb327bd890>,
#   '69179': <data.Game at 0x7feb30a72bd0>},
#  '2007/2008': {'68356': <data.Game at 0x7feb3e690dd0>,
#   '68358': <data.Game at 0x7feb37055ad0>,
#   '68359': <data.Game at 0x7feb400f6210>,
#   '68360': <data.Game at 0x7feb46349bd0>,
#   '68361': <data.Game at 0x7feb34dfe8d0>,
#   '68363': <data.Game at 0x7feb3b91fdd0>,
#   '68364': <data.Game at 0x7feb40bf7f90>,
#   '68365': <data.Game at 0x7feb417afc50>,
#   '68366': <data.Game at 0x7feb3a05d810>,
#   '69141': <data.Game at 0x7feb34226dd0>,
#   '69143': <data.Game at 0x7feb456b3e10>,
#   '69144': <data.Game at 0x7feb46fe7c90>,
#   '69145': <data.Game at 0x7feb364ec890>,
#   '69146': <data.Game at 0x7feb38916c90>,
#   '69148': <data.Game at 0x7feb3ac48c90>,
#   '69151': <data.Game at 0x7feb48e61a50>,
#   '69158': <data.Game at 0x7feb3cfc9f10>,
#   '69166': <data.Game at 0x7feb3c413e90>,
#   '69169': <data.Game at 0x7feb46353310>,
#   '69170': <data.Game at 0x7feb3f3d6950>,
#   '69173': <data.Game at 0x7feb37ce3750>,
#   '69178': <data.Game at 0x7feb430fa850>,
#   '69180': <data.Game at 0x7feb43c9de10>,
#   '69181': <data.Game at 0x7feb456b3ad0>,
#   '69182': <data.Game at 0x7feb364e3dd0>,
#   '69184': <data.Game at 0x7feb39432050>,
#   '69186': <data.Game at 0x7feb449aafd0>,
#   '69187': <data.Game at 0x7feb3daded90>},
#  '2008/2009': {'69138': <data.Game at 0x7feb4e2a7d90>,
#   '69139': <data.Game at 0x7feb528c70d0>,
#   '69142': <data.Game at 0x7feb54a2c050>,
#   '69147': <data.Game at 0x7feb59d46910>,
#   '69149': <data.Game at 0x7feb79510d50>,
#   '69171': <data.Game at 0x7feb506d6cd0>,
#   '69177': <data.Game at 0x7feb4cb1bed0>,
#   '69183': <data.Game at 0x7feb94713cd0>,
#   '69185': <data.Game at 0x7feb53499e10>,
#   '69189': <data.Game at 0x7feb51235f50>,
#   '69195': <data.Game at 0x7feb556a1d10>,
#   '69207': <data.Game at 0x7feb4be87d50>,
#   '69209': <data.Game at 0x7feb59d4cc90>,
#   '69211': <data.Game at 0x7feb93b971d0>,
#   '69212': <data.Game at 0x7feb5bf34fd0>,
#   '69215': <data.Game at 0x7feb5123ea10>,
#   '69216': <data.Game at 0x7feb59dbee50>,
#   '69217': <data.Game at 0x7feb57978f90>,
#   '69222': <data.Game at 0x7feb561c7c50>,
#   '69223': <data.Game at 0x7feb56d34490>,
#   '69225': <data.Game at 0x7feb5dd99810>,
#   '69228': <data.Game at 0x7feb4b2fbed0>,
#   '69230': <data.Game at 0x7feb4a784e10>,
#   '69231': <data.Game at 0x7feb585a2fd0>,
#   '69232': <data.Game at 0x7feb5a9bac50>,
#   '69235': <data.Game at 0x7feb5ca57f90>,
#   '69249': <data.Game at 0x7feb51c48210>,
#   '69251': <data.Game at 0x7feb53f4ce10>,
#   '69273': <data.Game at 0x7feb591e9310>,
#   '69279': <data.Game at 0x7feb9471a210>,
#   '69285': <data.Game at 0x7feb7a0d3810>},
#  '2009/2010': {'69210': <data.Game at 0x7feb6d898ed0>,
#   '69213': <data.Game at 0x7feb65a7a190>,
#   '69214': <data.Game at 0x7fecb2dfd450>,
#   '69218': <data.Game at 0x7feb72124e10>,
#   '69219': <data.Game at 0x7feb744934d0>,
#   '69220': <data.Game at 0x7feb6bf76cd0>,
#   '69221': <data.Game at 0x7feb5ed07c90>,
#   '69224': <data.Game at 0x7feb70a1a510>,
#   '69226': <data.Game at 0x7feb6b198f90>,
#   '69227': <data.Game at 0x7feb62ae1d10>,
#   '69229': <data.Game at 0x7feb738db910>,
#   '69233': <data.Game at 0x7feb673f2790>,
#   '69237': <data.Game at 0x7feb6cbc9d10>,
#   '69238': <data.Game at 0x7feb642d0f10>,
#   '69239': <data.Game at 0x7feb791ccd10>,
#   '69240': <data.Game at 0x7feb66700c10>,
#   '69241': <data.Game at 0x7feb784c3dd0>,
#   '69242': <data.Game at 0x7feb70a14cd0>,
#   '69243': <data.Game at 0x7feb7a999d50>,
#   '69244': <data.Game at 0x7feb7522be50>,
#   '69247': <data.Game at 0x7feb5fa21c10>,
#   '69250': <data.Game at 0x7feb714d6a50>,
#   '69252': <data.Game at 0x7feb697d6790>,
#   '69253': <data.Game at 0x7feb7606af90>,
#   '69254': <data.Game at 0x7feb61fbff50>,
#   '69255': <data.Game at 0x7feb68b81f50>,
#   '69256': <data.Game at 0x7feb7212e710>,
#   '69257': <data.Game at 0x7feb77800910>,
#   '69259': <data.Game at 0x7feb6e52ee90>,
#   '69262': <data.Game at 0x7febe7998e90>,
#   '69267': <data.Game at 0x7feb64dffed0>,
#   '69277': <data.Game at 0x7feb752337d0>,
#   '69288': <data.Game at 0x7feb636796d0>,
#   '69292': <data.Game at 0x7feb6126bcd0>,
#   '69298': <data.Game at 0x7feb6fe80d50>},
#  '2010/2011': {'69234': <data.Game at 0x7feb83ae4ed0>,
#   '69236': <data.Game at 0x7feb82dbd890>,
#   '69245': <data.Game at 0x7feb8daa18d0>,
#   '69246': <data.Game at 0x7feb89a59b10>,
#   '69248': <data.Game at 0x7feb7c3d97d0>,
#   '69260': <data.Game at 0x7febcff72110>,
#   '69263': <data.Game at 0x7feb7d07ffd0>,
#   '69269': <data.Game at 0x7febcff72ed0>,
#   '69270': <data.Game at 0x7feb8cb6de50>,
#   '69271': <data.Game at 0x7feb92922e50>,
#   '69272': <data.Game at 0x7feb813cfe10>,
#   '69274': <data.Game at 0x7feb88e03dd0>,
#   '69275': <data.Game at 0x7feb9023ca10>,
#   '69276': <data.Game at 0x7feb94e2fa10>,
#   '69278': <data.Game at 0x7feb8f569e50>,
#   '69280': <data.Game at 0x7feb85633f50>,
#   '69282': <data.Game at 0x7feb87f61dd0>,
#   '69283': <data.Game at 0x7feb87108190>,
#   '69286': <data.Game at 0x7feb8643d0d0>,
#   '69287': <data.Game at 0x7feb8b1376d0>,
#   '69289': <data.Game at 0x7feb813d5650>,
#   '69291': <data.Game at 0x7feb8474bc10>,
#   '69295': <data.Game at 0x7feb8e727bd0>,
#   '69296': <data.Game at 0x7febb4ff1fd0>,
#   '69299': <data.Game at 0x7feb7f76df50>,
#   '69300': <data.Game at 0x7feb804de710>,
#   '69302': <data.Game at 0x7feb8a682f90>,
#   '69303': <data.Game at 0x7feb8f574690>,
#   '69304': <data.Game at 0x7feb937507d0>,
#   '69305': <data.Game at 0x7feb90e79890>,
#   '69306': <data.Game at 0x7feb7dbe9a10>,
#   '69307': <data.Game at 0x7feb91b7b8d0>,
#   '69308': <data.Game at 0x7feb821e6910>},
#  '2011/2012': {'69264': <data.Game at 0x7feba5783c90>,
#   '69265': <data.Game at 0x7feba2f5cfd0>,
#   '69268': <data.Game at 0x7feba9964250>,
#   '69293': <data.Game at 0x7feba9964950>,
#   '69297': <data.Game at 0x7febab557a90>,
#   '69312': <data.Game at 0x7feb9c454d10>,
#   '69314': <data.Game at 0x7feb9a9f5a50>,
#   '69315': <data.Game at 0x7feba13d3d10>,
#   '69316': <data.Game at 0x7febaf92a610>,
#   '69318': <data.Game at 0x7feb99caff50>,
#   '69319': <data.Game at 0x7feba3d378d0>,
#   '69320': <data.Game at 0x7feb9ebb0ad0>,
#   '69322': <data.Game at 0x7febb1e7be10>,
#   '69323': <data.Game at 0x7feb9691c910>,
#   '69324': <data.Game at 0x7febaa63a6d0>,
#   '69325': <data.Game at 0x7febac1c2450>,
#   '69326': <data.Game at 0x7feb9dfaea50>,
#   '69327': <data.Game at 0x7feba0661950>,
#   '69328': <data.Game at 0x7febb529a290>,
#   '69329': <data.Game at 0x7febb43a2710>,
#   '69330': <data.Game at 0x7febad0eced0>,
#   '69331': <data.Game at 0x7febb12e4fd0>,
#   '69332': <data.Game at 0x7febb12ed850>,
#   '69333': <data.Game at 0x7feba64a4d10>,
#   '69334': <data.Game at 0x7feba213cd10>,
#   '69335': <data.Game at 0x7febaf92d950>,
#   '69336': <data.Game at 0x7feb9f8a5b50>,
#   '69337': <data.Game at 0x7febb06bcf50>,
#   '69338': <data.Game at 0x7feb99cafed0>,
#   '69340': <data.Game at 0x7feba498f990>,
#   '69343': <data.Game at 0x7feba714dad0>,
#   '70219': <data.Game at 0x7febb2c0ebd0>,
#   '70220': <data.Game at 0x7feb98ecba10>,
#   '70221': <data.Game at 0x7feb981e7d10>,
#   '70223': <data.Game at 0x7feba71c0dd0>,
#   '70224': <data.Game at 0x7feb97537b50>,
#   '70225': <data.Game at 0x7feba8d03f90>},
#  '2012/2013': {'266015': <data.Game at 0x7febd20da890>,
#   '266433': <data.Game at 0x7febc5875fd0>,
#   '266724': <data.Game at 0x7febcca8ecd0>,
#   '266827': <data.Game at 0x7febba3a0a50>,
#   '267502': <data.Game at 0x7febb9444dd0>,
#   '70256': <data.Game at 0x7febc7448790>,
#   '70259': <data.Game at 0x7febc4a10fd0>,
#   '70260': <data.Game at 0x7febc31bbd90>,
#   '70262': <data.Game at 0x7febb6a62190>,
#   '70263': <data.Game at 0x7febc24ab910>,
#   '70270': <data.Game at 0x7febce5f0e10>,
#   '70271': <data.Game at 0x7febb868df90>,
#   '70272': <data.Game at 0x7febcad04f90>,
#   '70275': <data.Game at 0x7febc0915e50>,
#   '70276': <data.Game at 0x7febc15f3dd0>,
#   '70280': <data.Game at 0x7febc839a7d0>,
#   '70281': <data.Game at 0x7febcf4134d0>,
#   '70282': <data.Game at 0x7febcbbb3c10>,
#   '70284': <data.Game at 0x7febbfcadf50>,
#   '70286': <data.Game at 0x7febc587e310>,
#   '70287': <data.Game at 0x7febc0915f50>,
#   '70292': <data.Game at 0x7febb5edec90>,
#   '70294': <data.Game at 0x7febb7838e10>,
#   '70295': <data.Game at 0x7febbce3bd50>,
#   '70296': <data.Game at 0x7febc839ad10>,
#   '70297': <data.Game at 0x7febc66b1d10>,
#   '70300': <data.Game at 0x7febcd8759d0>,
#   '70304': <data.Game at 0x7febc9188bd0>,
#   '70305': <data.Game at 0x7febbb364b50>,
#   '70307': <data.Game at 0x7febbc118f90>,
#   '70308': <data.Game at 0x7febcd875fd0>,
#   '70309': <data.Game at 0x7febe7854910>},
#  '2013/2014': {'265830': <data.Game at 0x7febd7b05790>,
#   '265837': <data.Game at 0x7febd46f2550>,
#   '265857': <data.Game at 0x7febd6043ad0>,
#   '265918': <data.Game at 0x7febdd466150>,
#   '266066': <data.Game at 0x7febe47dc790>,
#   '266074': <data.Game at 0x7febe06a5e90>,
#   '266201': <data.Game at 0x7febdf998f90>,
#   '266256': <data.Game at 0x7febda1a3a90>,
#   '266274': <data.Game at 0x7febde217ad0>,
#   '266420': <data.Game at 0x7febd20dae50>,
#   '266462': <data.Game at 0x7febd2e57790>,
#   '266491': <data.Game at 0x7febd9445810>,
#   '266603': <data.Game at 0x7febd6ddfe10>,
#   '266613': <data.Game at 0x7febd88e7e90>,
#   '266883': <data.Game at 0x7febd5354bd0>,
#   '267138': <data.Game at 0x7febe6c25950>,
#   '267192': <data.Game at 0x7febd3a2a550>,
#   '267368': <data.Game at 0x7febe798f9d0>,
#   '267520': <data.Game at 0x7febe538f5d0>,
#   '267567': <data.Game at 0x7febe2ce6ed0>,
#   '267675': <data.Game at 0x7febe2ce63d0>,
#   '70277': <data.Game at 0x7febdd45ab50>,
#   '70283': <data.Game at 0x7febdaeb7c50>,
#   '70288': <data.Game at 0x7febe1248fd0>,
#   '70289': <data.Game at 0x7febe39fff50>,
#   '70291': <data.Game at 0x7febe6046dd0>,
#   '70293': <data.Game at 0x7febdd45ab90>,
#   '70298': <data.Game at 0x7fec05e8c750>,
#   '70301': <data.Game at 0x7fec20861f10>,
#   '70302': <data.Game at 0x7fec06be0850>,
#   '70306': <data.Game at 0x7febdbaa2210>},
#  '2014/2015': {'265835': <data.Game at 0x7fec07591790>,
#   '265866': <data.Game at 0x7fec0024a350>,
#   '265896': <data.Game at 0x7febff582e10>,
#   '265963': <data.Game at 0x7fec05cec710>,
#   '266045': <data.Game at 0x7febf906a750>,
#   '266117': <data.Game at 0x7fec043e3150>,
#   '266142': <data.Game at 0x7febe86ebe50>,
#   '266148': <data.Game at 0x7febfb5b8c50>,
#   '266230': <data.Game at 0x7febf222bfd0>,
#   '266240': <data.Game at 0x7febf839ac10>,
#   '266320': <data.Game at 0x7febf3cb0690>,
#   '266406': <data.Game at 0x7febfc16dd10>,
#   '266525': <data.Game at 0x7febf3029d50>,
#   '266531': <data.Game at 0x7febeecdadd0>,
#   '266560': <data.Game at 0x7febf14d4fd0>,
#   '266631': <data.Game at 0x7febf3cb0d90>,
#   '266741': <data.Game at 0x7febec6caf10>,
#   '266770': <data.Game at 0x7febeadf9d10>,
#   '266794': <data.Game at 0x7febf528ab50>,
#   '266838': <data.Game at 0x7fec04f2add0>,
#   '266846': <data.Game at 0x7febefa8e910>,
#   '266871': <data.Game at 0x7febee01b110>,
#   '266916': <data.Game at 0x7fec02a01dd0>,
#   '266921': <data.Game at 0x7febee00fed0>,
#   '266929': <data.Game at 0x7febea07ef90>,
#   '266967': <data.Game at 0x7febebac3550>,
#   '267085': <data.Game at 0x7febfa896fd0>,
#   '267183': <data.Game at 0x7fec0368d9d0>,
#   '267197': <data.Game at 0x7fec01d8fb10>,
#   '267301': <data.Game at 0x7febfe7b9f90>,
#   '267343': <data.Game at 0x7febf46b5850>,
#   '267400': <data.Game at 0x7febfdb5cd90>,
#   '267499': <data.Game at 0x7febf0792290>,
#   '267561': <data.Game at 0x7febf9b9afd0>,
#   '267597': <data.Game at 0x7febf6bc3950>,
#   '70264': <data.Game at 0x7fec002c1f50>,
#   '70273': <data.Game at 0x7febff57cfd0>,
#   '70303': <data.Game at 0x7febf778acd0>},
#  '2015/2016': {'265839': <data.Game at 0x7fec0c353c90>,
#   '265894': <data.Game at 0x7fec1ac8a4d0>,
#   '265944': <data.Game at 0x7fec1c4685d0>,
#   '265958': <data.Game at 0x7fec19575f10>,
#   '266056': <data.Game at 0x7fec0f782cd0>,
#   '266106': <data.Game at 0x7fec13213dd0>,
#   '266149': <data.Game at 0x7fec1030ac90>,
#   '266160': <data.Game at 0x7fec17e31050>,
#   '266166': <data.Game at 0x7fec0e9d7cd0>,
#   '266236': <data.Game at 0x7fec18a30e50>,
#   '266254': <data.Game at 0x7fec0a87ad50>,
#   '266310': <data.Game at 0x7fec1d1fabd0>,
#   '266424': <data.Game at 0x7fec0c11e750>,
#   '266467': <data.Game at 0x7fec1a0631d0>,
#   '266490': <data.Game at 0x7fec09ab2b10>,
#   '266498': <data.Game at 0x7fec39b81850>,
#   '266557': <data.Game at 0x7fec08de8710>,
#   '266620': <data.Game at 0x7fecafd7dd90>,
#   '266653': <data.Game at 0x7fec1d201410>,
#   '266664': <data.Game at 0x7fec1271ac50>,
#   '266670': <data.Game at 0x7fec11b34bd0>,
#   '266815': <data.Game at 0x7fec13ed0e90>,
#   '266885': <data.Game at 0x7fec16583910>,
#   '266961': <data.Game at 0x7fec158bff50>,
#   '266986': <data.Game at 0x7fec1eaf2c90>,
#   '267273': <data.Game at 0x7fec0b43ef10>,
#   '267274': <data.Game at 0x7fec165f9bd0>,
#   '267327': <data.Game at 0x7fec0dc87ed0>,
#   '267422': <data.Game at 0x7fec17e2dbd0>,
#   '267506': <data.Game at 0x7fecafd7df50>,
#   '267533': <data.Game at 0x7fec1de77c90>,
#   '267576': <data.Game at 0x7fec1de7ea10>,
#   '267611': <data.Game at 0x7fec19504c10>},
#  '2016/2017': {'265952': <data.Game at 0x7fec23ec5fd0>,
#   '266033': <data.Game at 0x7fec312ca350>,
#   '266191': <data.Game at 0x7fec258279d0>,
#   '266273': <data.Game at 0x7fec2e12ee50>,
#   '266280': <data.Game at 0x7fec35d19ed0>,
#   '266299': <data.Game at 0x7fec26285cd0>,
#   '266357': <data.Game at 0x7fec38ea7f50>,
#   '266440': <data.Game at 0x7fec305fbad0>,
#   '266477': <data.Game at 0x7fec337dff10>,
#   '266516': <data.Game at 0x7fec35173590>,
#   '266528': <data.Game at 0x7fec3b1f9290>,
#   '266669': <data.Game at 0x7fec3690df90>,
#   '266731': <data.Game at 0x7fec2bc82b50>,
#   '266874': <data.Game at 0x7fec2d45a9d0>,
#   '266892': <data.Game at 0x7fec38116d10>,
#   '266952': <data.Game at 0x7fec270c2d50>,
#   '266989': <data.Game at 0x7fec3ca86bd0>,
#   '267039': <data.Game at 0x7fec32c709d0>,
#   '267058': <data.Game at 0x7fec232d5690>,
#   '267076': <data.Game at 0x7fec57b54bd0>,
#   '267077': <data.Game at 0x7fec746fc650>,
#   '267101': <data.Game at 0x7fec3133fb90>,
#   '267212': <data.Game at 0x7fec37497f90>,
#   '267220': <data.Game at 0x7fec35d21110>,
#   '267373': <data.Game at 0x7fec28a34610>,
#   '267395': <data.Game at 0x7fec2f9e7050>,
#   '267432': <data.Game at 0x7fec2a42d0d0>,
#   '267464': <data.Game at 0x7fec28a34e10>,
#   '267492': <data.Game at 0x7fec23ed1a90>,
#   '267569': <data.Game at 0x7fec3a1ac250>,
#   '267590': <data.Game at 0x7fec746fc790>,
#   '267596': <data.Game at 0x7fec22645750>,
#   '267660': <data.Game at 0x7fec2eda3a10>,
#   '267670': <data.Game at 0x7fec343c9dd0>},
#  '2017/2018': {'9575': <data.Game at 0x7fec5686b710>,
#   '9581': <data.Game at 0x7fec3e585d50>,
#   '9592': <data.Game at 0x7fec4e4b1fd0>,
#   '9602': <data.Game at 0x7fec40a10c50>,
#   '9609': <data.Game at 0x7fec575c7e90>,
#   '9620': <data.Game at 0x7fec46233ed0>,
#   '9636': <data.Game at 0x7fec74c6a9d0>,
#   '9642': <data.Game at 0x7fec423a8b50>,
#   '9650': <data.Game at 0x7fec48bb7110>,
#   '9661': <data.Game at 0x7fec4f0a8f10>,
#   '9673': <data.Game at 0x7fec47da9e90>,
#   '9682': <data.Game at 0x7fec3fe32f10>,
#   '9695': <data.Game at 0x7fec4cb4c0d0>,
#   '9700': <data.Game at 0x7fec4c0ffcd0>,
#   '9717': <data.Game at 0x7fec74327f10>,
#   '9726': <data.Game at 0x7fec3d85fe50>,
#   '9736': <data.Game at 0x7fec55c01b50>,
#   '9742': <data.Game at 0x7fec5405d710>,
#   '9754': <data.Game at 0x7fec3f1acd10>,
#   '9765': <data.Game at 0x7fec53298890>,
#   '9774': <data.Game at 0x7fec4302cd50>,
#   '9783': <data.Game at 0x7fec4cb44c90>,
#   '9794': <data.Game at 0x7fec4981cf90>,
#   '9799': <data.Game at 0x7fec58518690>,
#   '9811': <data.Game at 0x7fec45656610>,
#   '9827': <data.Game at 0x7fec4564d790>,
#   '9837': <data.Game at 0x7fec44af2c50>,
#   '9855': <data.Game at 0x7fec5261a950>,
#   '9860': <data.Game at 0x7fec4d878110>,
#   '9870': <data.Game at 0x7fecbc7372d0>,
#   '9880': <data.Game at 0x7fec50beedd0>,
#   '9889': <data.Game at 0x7fec3ca860d0>,
#   '9912': <data.Game at 0x7fec4564dd10>,
#   '9924': <data.Game at 0x7fec51892690>,
#   '9928': <data.Game at 0x7fec54e08d90>,
#   '9948': <data.Game at 0x7fec4166fa50>},
#  '2018/2019': {'15946': <data.Game at 0x7fec6a5d5ed0>,
#   '15956': <data.Game at 0x7fec5d58d910>,
#   '15973': <data.Game at 0x7fec6753a810>,
#   '15978': <data.Game at 0x7fec5c900cd0>,
#   '15986': <data.Game at 0x7fec5fe4b850>,
#   '15998': <data.Game at 0x7fec74e84c10>,
#   '16010': <data.Game at 0x7fec5efd8850>,
#   '16023': <data.Game at 0x7fec5d58dd10>,
#   '16029': <data.Game at 0x7fec7389c110>,
#   '16056': <data.Game at 0x7fec6818ee10>,
#   '16073': <data.Game at 0x7fec71f0aad0>,
#   '16079': <data.Game at 0x7fec66807b10>,
#   '16086': <data.Game at 0x7fec72b4ed10>,
#   '16095': <data.Game at 0x7fec60b09710>,
#   '16109': <data.Game at 0x7fec6f79a8d0>,
#   '16120': <data.Game at 0x7fec6e987fd0>,
#   '16131': <data.Game at 0x7fec6264b8d0>,
#   '16136': <data.Game at 0x7fec6a5d5d10>,
#   '16149': <data.Game at 0x7fec659ddd90>,
#   '16157': <data.Game at 0x7fec6ce15250>,
#   '16173': <data.Game at 0x7fec6c096dd0>,
#   '16182': <data.Game at 0x7fec70406790>,
#   '16190': <data.Game at 0x7fec711a5e90>,
#   '16196': <data.Game at 0x7fec5ba99e90>,
#   '16205': <data.Game at 0x7fec633aef90>,
#   '16215': <data.Game at 0x7fec6ce0ee10>,
#   '16231': <data.Game at 0x7fec591c9dd0>,
#   '16240': <data.Game at 0x7fec5e376c10>,
#   '16248': <data.Game at 0x7fec8f9fcf90>,
#   '16265': <data.Game at 0x7fec6b3bae50>,
#   '16275': <data.Game at 0x7fec64cdbfd0>,
#   '16289': <data.Game at 0x7fec67532d10>,
#   '16306': <data.Game at 0x7fec618e2f90>,
#   '16317': <data.Game at 0x7fec6405af90>},
#  '2019/2020': {'303377': <data.Game at 0x7fec7a8ff610>,
#   '303400': <data.Game at 0x7fec896ff9d0>,
#   '303421': <data.Game at 0x7fec86107dd0>,
#   '303430': <data.Game at 0x7fecada6d250>,
#   '303451': <data.Game at 0x7fecae2d5890>,
#   '303470': <data.Game at 0x7fec7dd64490>,
#   '303473': <data.Game at 0x7fec75b55f90>,
#   '303479': <data.Game at 0x7fec853f8a10>,
#   '303487': <data.Game at 0x7fec81292f90>,
#   '303493': <data.Game at 0x7fec86e2b610>,
#   '303504': <data.Game at 0x7fecada468d0>,
#   '303516': <data.Game at 0x7fec8de6a590>,
#   '303517': <data.Game at 0x7fec790c4d50>,
#   '303524': <data.Game at 0x7fec7855eed0>,
#   '303532': <data.Game at 0x7fec8de62c10>,
#   '303548': <data.Game at 0x7fec80565990>,
#   '303596': <data.Game at 0x7fecada6d2d0>,
#   '303600': <data.Game at 0x7fec82c7e990>,
#   '303610': <data.Game at 0x7fec76ac3d50>,
#   '303615': <data.Game at 0x7fec82c76cd0>,
#   '303634': <data.Game at 0x7fec87b91e90>,
#   '303652': <data.Game at 0x7fec7eaa3e90>,
#   '303664': <data.Game at 0x7fec8a501950>,
#   '303666': <data.Game at 0x7fec7cf8c3d0>,
#   '303674': <data.Game at 0x7fec7dd5dfd0>,
#   '303680': <data.Game at 0x7fec8465de10>,
#   '303682': <data.Game at 0x7fec8895ea90>,
#   '303696': <data.Game at 0x7fec81faafd0>,
#   '303700': <data.Game at 0x7fec7c19ab10>,
#   '303707': <data.Game at 0x7fec7cf86e90>,
#   '303715': <data.Game at 0x7fec79d53950>,
#   '303725': <data.Game at 0x7fec8bfe6890>,
#   '303731': <data.Game at 0x7fec90005d90>},
#  '2020/2021': {'3764440': <data.Game at 0x7fec935ecd10>,
#   '3764661': <data.Game at 0x7fec9bca7790>,
#   '3773369': <data.Game at 0x7fecafa86250>,
#   '3773372': <data.Game at 0x7fecad6f43d0>,
#   '3773377': <data.Game at 0x7feca841dd90>,
#   '3773386': <data.Game at 0x7feca776afd0>,
#   '3773387': <data.Game at 0x7fecad7a1ad0>,
#   '3773403': <data.Game at 0x7fec95db2990>,
#   '3773415': <data.Game at 0x7fec95dc2650>,
#   '3773428': <data.Game at 0x7fec99344d50>,
#   '3773457': <data.Game at 0x7fecada7e7d0>,
#   '3773466': <data.Game at 0x7feca3608950>,
#   '3773474': <data.Game at 0x7fec96b28a10>,
#   '3773477': <data.Game at 0x7fec91a65d90>,
#   '3773497': <data.Game at 0x7fec9ca62590>,
#   '3773523': <data.Game at 0x7fec9d69bfd0>,
#   '3773526': <data.Game at 0x7fec98615590>,
#   '3773547': <data.Game at 0x7fec94391850>,
#   '3773552': <data.Game at 0x7feca1b95f90>,
#   '3773565': <data.Game at 0x7feca6914f90>,
#   '3773571': <data.Game at 0x7fec9e40ba10>,
#   '3773585': <data.Game at 0x7feca4f3c610>,
#   '3773586': <data.Game at 0x7feca9fb0850>,
#   '3773587': <data.Game at 0x7feca4f3cc50>,
#   '3773593': <data.Game at 0x7feca0dc0c10>,
#   '3773597': <data.Game at 0x7fec9e405dd0>,
#   '3773625': <data.Game at 0x7fec95db2c90>,
#   '3773631': <data.Game at 0x7fec9d6a2a90>,
#   '3773656': <data.Game at 0x7feca9203250>,
#   '3773660': <data.Game at 0x7fec9fef7dd0>,
#   '3773661': <data.Game at 0x7fec9f1d1f90>,
#   '3773665': <data.Game at 0x7fec9a1a4510>,
#   '3773672': <data.Game at 0x7feca447bdd0>,
#   '3773689': <data.Game at 0x7fec91a65e10>,
#   '3773695': <data.Game at 0x7fecad6ef090>}}

# %%
with open('laliga.pickle', 'wb') as handle:
    pkl.dump(laliga, handle, protocol=pkl.HIGHEST_PROTOCOL)

# %%
with open('laliga.pickle', 'rb') as handle:
    b = pkl.load(handle)

# %%
laliga_shots = obtain_all_shots(laliga)
# Out:
# Obtaining shots for 2020/2021
# Obtaining shots for 2019/2020
# Obtaining shots for 2018/2019
# Obtaining shots for 2017/2018
# Obtaining shots for 2016/2017
# Obtaining shots for 2015/2016
# Obtaining shots for 2014/2015
# Obtaining shots for 2013/2014
# Obtaining shots for 2012/2013
# Obtaining shots for 2011/2012
# Obtaining shots for 2010/2011
# Obtaining shots for 2009/2010
# Obtaining shots for 2008/2009
# Obtaining shots for 2007/2008
# Obtaining shots for 2006/2007
# Obtaining shots for 2005/2006
# Obtaining shots for 2004/2005
# Done.

# %%
laliga_shots
# Out:
#                                  shot id    play pattern  x location shot  \
# 0   859f0f2d-6b33-49a3-9397-64d2ab927a73    From Counter            107.1
# 1   7a1b1dcb-4e09-4bfa-9827-9d81b6944bc5   From Throw In             99.3
# 2   5078ef4c-43ea-4e5e-90cc-8c288349b3e3    Regular Play             99.4
# 3   3b87f877-45b9-425c-8d0c-035975f7f0cf   From Throw In            108.0
# 4   06c3d431-8ac3-43fa-9585-d9689f7a44f3   From Throw In            104.1
# ..                                   ...             ...              ...
# 20  4468faac-ae6a-4637-928b-fc7dd448411b  From Free Kick             91.1
# 21  5f613006-c00e-4581-882c-a7a81978ebf0   From Throw In            103.7
# 22  717c9351-6eff-4f71-969a-e25bab5bfcb6   From Throw In            107.9
# 23  0c914938-af14-479e-8043-8e4bfdfd474d   From Throw In            117.8
# 24  d9533117-d840-4973-91cd-9472a76d705e  From Free Kick            108.5
#
#     y location shot  duration outcome technique used  first time  \
# 0              57.2  0.615658   Saved         Normal       False
# 1              55.1  0.762260   Saved         Normal       False
# 2              33.0  1.847193    Goal         Normal       False
# 3              34.2  0.914051   Off T         Normal       False
# 4              43.0  0.642854   Saved         Normal       False
# ..              ...       ...     ...            ...         ...
# 20             47.1  1.622413    Post         Normal       False
# 21             33.6  1.070861   Off T    Half Volley       False
# 22             37.0  0.701300   Saved         Volley        True
# 23             43.9  1.256200    Post         Normal       False
# 24             45.6  1.316500   Off T         Normal       False
#
#     x gk location  y gk location  ... type of shot  \
# 0           117.4           44.0  ...    Open Play
# 1           117.9           41.9  ...    Open Play
# 2           117.5           38.5  ...    Open Play
# 3           117.4           38.5  ...    Open Play
# 4           117.1           41.4  ...    Open Play
# ..            ...            ...  ...          ...
# 20          118.4           40.8  ...    Free Kick
# 21          119.5           39.8  ...    Open Play
# 22          119.2           39.6  ...    Open Play
# 23          118.9           43.3  ...    Open Play
# 24          119.6           41.4  ...    Open Play
#
#    Number of opponents in 5 yards  Players between goal  \
# 0                               2                     1
# 1                               1                     1
# 2                               3                     2
# 3                               5                     2
# 4                               3                     2
# ..                            ...                   ...
# 20                              0                     5
# 21                              3                     1
# 22                              2                     2
# 23                              1                     1
# 24                              1                     1
#
#                              player name  Team Name official xg  \
# 0                     Rafael Mir Vicente     Huesca    0.029275
# 1                           Sergino Dest  Barcelona    0.036545
# 2         Lionel Andrés Messi Cuccittini  Barcelona    0.041210
# 3         Lionel Andrés Messi Cuccittini  Barcelona    0.136125
# 4                   Pablo Maffeo Becerra     Huesca    0.095665
# ..                                   ...        ...         ...
# 20              Giovanni van Bronckhorst  Barcelona    0.049559
# 21             Ferrán Corominas Telechea   Espanyol    0.057103
# 22  Mauricio Roberto Pochettino Trossero   Espanyol    0.113389
# 23             Ferrán Corominas Telechea   Espanyol    0.415576
# 24  Mauricio Roberto Pochettino Trossero   Espanyol    0.051609
#
#                                  Pass id    Pass Type  game_id  season_id
# 0   e040e36e-15d7-42f5-8d9b-378139572208     Low Pass  3773369  2020/2021
# 1                                No Pass         None  3773369  2020/2021
# 2   80c324ab-5504-4eba-9f9b-0c8ee58d5f64  Ground Pass  3773369  2020/2021
# 3   bd61aa8e-9621-4bd1-be83-b2bbb9dfee4f  Ground Pass  3773369  2020/2021
# 4   b8f27912-bac9-4950-8086-33404437d953  Ground Pass  3773369  2020/2021
# ..                                   ...          ...      ...        ...
# 20                               No Pass         None    68353  2004/2005
# 21                               No Pass         None    68353  2004/2005
# 22  dbaca88f-32d3-4abe-a37d-4fceb67a4302     Low Pass    68353  2004/2005
# 23                               No Pass         None    68353  2004/2005
# 24  f2137b0f-01b5-4311-8eea-955918e63892    High Pass    68353  2004/2005
#
# [12841 rows x 21 columns]

# %%
laliga_shots['distance_from_goalpost_a'] = np.sqrt((laliga_shots['x location shot']-120)**2+(laliga_shots['y location shot']-36)**2)
laliga_shots['distance_from_goalpost_b'] = np.sqrt((laliga_shots['x location shot']-120)**2+(laliga_shots['y location shot']-44)**2)

laliga_shots['shot_angle'] = np.arccos((laliga_shots['distance_from_goalpost_a']**2+laliga_shots['distance_from_goalpost_b']**2-64)/(2*laliga_shots['distance_from_goalpost_a']*laliga_shots['distance_from_goalpost_b']))
laliga_shots['shot_angle'] = np.degrees(laliga_shots['shot_angle'])
laliga_shots['shot_angle'] = round(laliga_shots['shot_angle'],1)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py:364: RuntimeWarning: invalid value encountered in arccos
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
laliga_shots
# Out:
#                                  shot id    play pattern  x location shot  \
# 0   859f0f2d-6b33-49a3-9397-64d2ab927a73    From Counter            107.1
# 1   7a1b1dcb-4e09-4bfa-9827-9d81b6944bc5   From Throw In             99.3
# 2   5078ef4c-43ea-4e5e-90cc-8c288349b3e3    Regular Play             99.4
# 3   3b87f877-45b9-425c-8d0c-035975f7f0cf   From Throw In            108.0
# 4   06c3d431-8ac3-43fa-9585-d9689f7a44f3   From Throw In            104.1
# ..                                   ...             ...              ...
# 20  4468faac-ae6a-4637-928b-fc7dd448411b  From Free Kick             91.1
# 21  5f613006-c00e-4581-882c-a7a81978ebf0   From Throw In            103.7
# 22  717c9351-6eff-4f71-969a-e25bab5bfcb6   From Throw In            107.9
# 23  0c914938-af14-479e-8043-8e4bfdfd474d   From Throw In            117.8
# 24  d9533117-d840-4973-91cd-9472a76d705e  From Free Kick            108.5
#
#     y location shot  duration outcome technique used  first time  \
# 0              57.2  0.615658   Saved         Normal       False
# 1              55.1  0.762260   Saved         Normal       False
# 2              33.0  1.847193    Goal         Normal       False
# 3              34.2  0.914051   Off T         Normal       False
# 4              43.0  0.642854   Saved         Normal       False
# ..              ...       ...     ...            ...         ...
# 20             47.1  1.622413    Post         Normal       False
# 21             33.6  1.070861   Off T    Half Volley       False
# 22             37.0  0.701300   Saved         Volley        True
# 23             43.9  1.256200    Post         Normal       False
# 24             45.6  1.316500   Off T         Normal       False
#
#     x gk location  y gk location  ...                           player name  \
# 0           117.4           44.0  ...                    Rafael Mir Vicente
# 1           117.9           41.9  ...                          Sergino Dest
# 2           117.5           38.5  ...        Lionel Andrés Messi Cuccittini
# 3           117.4           38.5  ...        Lionel Andrés Messi Cuccittini
# 4           117.1           41.4  ...                  Pablo Maffeo Becerra
# ..            ...            ...  ...                                   ...
# 20          118.4           40.8  ...              Giovanni van Bronckhorst
# 21          119.5           39.8  ...             Ferrán Corominas Telechea
# 22          119.2           39.6  ...  Mauricio Roberto Pochettino Trossero
# 23          118.9           43.3  ...             Ferrán Corominas Telechea
# 24          119.6           41.4  ...  Mauricio Roberto Pochettino Trossero
#
#     Team Name  official xg                               Pass id    Pass Type  \
# 0      Huesca     0.029275  e040e36e-15d7-42f5-8d9b-378139572208     Low Pass
# 1   Barcelona     0.036545                               No Pass         None
# 2   Barcelona     0.041210  80c324ab-5504-4eba-9f9b-0c8ee58d5f64  Ground Pass
# 3   Barcelona     0.136125  bd61aa8e-9621-4bd1-be83-b2bbb9dfee4f  Ground Pass
# 4      Huesca     0.095665  b8f27912-bac9-4950-8086-33404437d953  Ground Pass
# ..        ...          ...                                   ...          ...
# 20  Barcelona     0.049559                               No Pass         None
# 21   Espanyol     0.057103                               No Pass         None
# 22   Espanyol     0.113389  dbaca88f-32d3-4abe-a37d-4fceb67a4302     Low Pass
# 23   Espanyol     0.415576                               No Pass         None
# 24   Espanyol     0.051609  f2137b0f-01b5-4311-8eea-955918e63892    High Pass
#
#     game_id  season_id distance_from_goalpost_a distance_from_goalpost_b  \
# 0   3773369  2020/2021                24.816325                18.456706
# 1   3773369  2020/2021                28.165582                23.488295
# 2   3773369  2020/2021                20.817300                23.352944
# 3   3773369  2020/2021                12.134249                15.493224
# 4   3773369  2020/2021                17.372680                15.931416
# ..      ...        ...                      ...                      ...
# 20    68353  2004/2005                30.958359                29.065787
# 21    68353  2004/2005                16.475740                19.335201
# 22    68353  2004/2005                12.141252                13.978913
# 23    68353  2004/2005                 8.200610                 2.202272
# 24    68353  2004/2005                14.980320                11.610771
#
#    shot_angle
# 0        13.0
# 1        14.5
# 2        19.8
# 3        30.7
# 4        27.4
# ..        ...
# 20       14.9
# 21       24.2
# 22       34.8
# 23       77.0
# 24       31.9
#
# [12841 rows x 24 columns]

# %%
laliga_shots.isna().sum()
# Out:
# shot id                           0
# play pattern                      0
# x location shot                   0
# y location shot                   0
# duration                          0
# outcome                           0
# technique used                    0
# first time                        0
# x gk location                     0
# y gk location                     0
# body part                         0
# type of shot                      0
# Number of opponents in 5 yards    0
# Players between goal              0
# player name                       0
# Team Name                         0
# official xg                       0
# Pass id                           0
# Pass Type                         0
# game_id                           0
# season_id                         0
# distance_from_goalpost_a          0
# distance_from_goalpost_b          0
# shot_angle                        1
# dtype: int64

# %%
laliga_shots[laliga_shots['shot_angle'].isna()]
# Out:
#                                  shot id    play pattern  x location shot  \
# 24  7540f106-869b-4cb8-8a6b-d1db41f7b759  From Free Kick            120.0
#
#     y location shot  duration outcome technique used  first time  \
# 24             43.7    0.3009    Goal         Normal        True
#
#     x gk location  y gk location  ...               player name  Team Name  \
# 24          113.2           33.3  ...  Luis Alberto Suárez Díaz  Barcelona
#
#     official xg  Pass id Pass Type game_id  season_id  \
# 24     0.898411  No Pass      None  266254  2015/2016
#
#    distance_from_goalpost_a distance_from_goalpost_b shot_angle
# 24                      7.7                      0.3        NaN
#
# [1 rows x 24 columns]

# %%
laliga_shots['shot_angle']=laliga_shots['shot_angle'].fillna(0)

# %%
laliga_shots.isna().sum()
# Out:
# shot id                           0
# play pattern                      0
# x location shot                   0
# y location shot                   0
# duration                          0
# outcome                           0
# technique used                    0
# first time                        0
# x gk location                     0
# y gk location                     0
# body part                         0
# type of shot                      0
# Number of opponents in 5 yards    0
# Players between goal              0
# player name                       0
# Team Name                         0
# official xg                       0
# Pass id                           0
# Pass Type                         0
# game_id                           0
# season_id                         0
# distance_from_goalpost_a          0
# distance_from_goalpost_b          0
# shot_angle                        0
# dtype: int64

# %%
laliga_shots.to_pickle('./laliga_data.pkl')

# %%
df = pd.read_pickle('./data.pkl')

# %%
df
# Out:
#                                     shot id    play pattern  x location shot  \
# 0      56deeffa-ff55-429e-91df-41f237a3ebac    Regular Play            103.7
# 1      00d9c066-1078-4e1c-8c7f-2ca299e3a5f0  From Free Kick            107.4
# 2      48706448-928f-4721-96ec-2b813f448937    Regular Play            108.5
# 3      718f8a06-078c-489e-9423-63d414be5e43   From Throw In            106.0
# 4      e1b29724-4861-4d12-9a51-ac6635e97438     From Corner            112.4
# ...                                     ...             ...              ...
# 10671  eb30353e-0e71-4d7c-9b25-81cdabf5f00c     From Corner            113.0
# 10672  3b84e678-d070-4350-a1de-5ba6999ae0a6    Regular Play            101.0
# 10673  8e16e1ea-3551-4ae5-a997-5b3abd5bf878    Regular Play             95.0
# 10674  144adbf6-38c8-4828-869d-aa8df0b959d9     From Corner            116.0
# 10675  7a7e8c81-1a03-4e6e-ac56-a53321821008   From Throw In            113.0
#
#        y location shot  duration  outcome technique used  first time  \
# 0                 46.3  0.909600    Saved         Normal        True
# 1                 37.4  1.033500     Goal         Normal       False
# 2                 48.1  1.391602    Off T         Normal       False
# 3                 43.7  1.154700    Saved         Normal       False
# 4                 42.9  0.907511    Off T         Normal       False
# ...                ...       ...      ...            ...         ...
# 10671             35.0  0.614701  Blocked         Volley        True
# 10672             25.0  1.707811  Wayward         Normal       False
# 10673             53.0  1.191144    Saved         Normal       False
# 10674             39.0  0.407400     Goal         Normal       False
# 10675             43.0  0.383071  Blocked         Normal       False
#
#        x gk location  y gk location  ...        player name  \
# 0              116.0           43.0  ...  Samantha May Kerr
# 1              118.3           39.9  ...  Samantha May Kerr
# 2              118.9           42.8  ...  Samantha May Kerr
# 3              118.9           42.1  ...  Samantha May Kerr
# 4              119.3           40.7  ...  Samantha May Kerr
# ...              ...            ...  ...                ...
# 10671          118.0           39.0  ...   Felicity Gibbons
# 10672          119.0           40.0  ...       Marisa Ewers
# 10673          119.0           42.0  ...   Charlie Wellings
# 10674          118.0           39.0  ...       Ellie Brazil
# 10675          119.0           43.0  ...       Chloe Arthur
#
#                         Team Name  official xg  \
# 0               Australia Women's     0.174474
# 1               Australia Women's     0.028797
# 2               Australia Women's     0.027564
# 3               Australia Women's     0.025206
# 4               Australia Women's     0.065884
# ...                           ...          ...
# 10671  Brighton & Hove Albion WFC     0.080659
# 10672         Birmingham City WFC     0.026853
# 10673         Birmingham City WFC     0.013686
# 10674  Brighton & Hove Albion WFC     0.290824
# 10675         Birmingham City WFC     0.403313
#
#                                     Pass id    Pass Type game_id  season_id  \
# 0      448cb3aa-ee0b-4829-a7d4-bdef6dfda5bd  Ground Pass   68311       2019
# 1      f5d55ee4-2db3-4604-b9fa-8bd0645fdc4b    High Pass   68311       2019
# 2      13eaef4e-1393-4b99-b94d-d60c35070713    High Pass   68311       2019
# 3      be417f5e-798b-4dd0-a651-4b7a9d2e3564    High Pass   68311       2019
# 4      ef4852cb-22f5-4afe-8355-5ec0752f9adb    High Pass   68311       2019
# ...                                     ...          ...     ...        ...
# 10671  838f8082-25da-4550-b4f9-7082850e76c4    High Pass   19796  2018/2019
# 10672                               No Pass         None   19796  2018/2019
# 10673  814a0ef6-71f6-43a7-acb4-d896b44000ce  Ground Pass   19796  2018/2019
# 10674  4f49d0c7-9161-4e22-add0-2b1b12c5f352    High Pass   19796  2018/2019
# 10675                               No Pass         None   19796  2018/2019
#
#       distance_from_goalpost_a distance_from_goalpost_b shot_angle
# 0                    19.281597                16.461470       24.3
# 1                    12.677539                14.223924       34.0
# 2                    16.693112                12.209013       26.8
# 3                    15.977797                14.003214       30.0
# 4                    10.264989                 7.679193       50.5
# ...                        ...                      ...        ...
# 10671                 7.071068                11.401754       44.0
# 10672                21.954498                26.870058       14.9
# 10673                30.232433                26.570661       14.4
# 10674                 5.000000                 6.403124       88.2
# 10675                 9.899495                 7.071068       53.1
#
# [10676 rows x 24 columns]

# %%
df.isna().sum()
# Out:
# shot id                           0
# play pattern                      0
# x location shot                   0
# y location shot                   0
# duration                          0
# outcome                           0
# technique used                    0
# first time                        0
# x gk location                     1
# y gk location                     1
# body part                         0
# type of shot                      0
# Number of opponents in 5 yards    0
# Players between goal              0
# player name                       0
# Team Name                         0
# official xg                       0
# Pass id                           0
# Pass Type                         0
# game_id                           0
# season_id                         0
# distance_from_goalpost_a          0
# distance_from_goalpost_b          0
# shot_angle                        2
# dtype: int64

# %%
df[df['shot_angle'].isna()]
# Out:
#                                    shot id  play pattern  x location shot  \
# 2820  43fc3329-220a-4141-a948-e79082759be7   From Corner            120.0
# 6667  438b2bc2-8f54-4c4d-8971-7e6efaa96e5a  Regular Play            120.0
#
#       y location shot  duration outcome technique used  first time  \
# 2820             34.7  0.899775   Off T         Normal       False
# 6667             30.6  0.276294   Saved         Normal       False
#
#       x gk location  y gk location  ...          player name  \
# 2820          119.3           37.4  ...  Samantha June Mewis
# 6667          119.6           36.3  ...         Lauren James
#
#                 Team Name  official xg                               Pass id  \
# 2820  Manchester City WFC     0.139676  c2446bcc-6442-481d-a360-49f862953de9
# 6667    Manchester United     0.067796                               No Pass
#
#       Pass Type  game_id  season_id distance_from_goalpost_a  \
# 2820  High Pass  3775624  2020/2021                      1.3
# 6667       None  2275139  2019/2020                      5.4
#
#      distance_from_goalpost_b shot_angle
# 2820                      9.3        NaN
# 6667                     13.4        NaN
#
# [2 rows x 24 columns]

# %%
df['shot_angle']=df['shot_angle'].fillna(0)

# %%
df[df['x gk location'].isna()]
# Out:
#                                    shot id    play pattern  x location shot  \
# 8461  9c60dc1c-16e8-40d0-9522-665e7993c188  From Free Kick             96.0
#
#       y location shot  duration  outcome technique used  first time  \
# 8461             50.0    0.6414  Blocked         Normal       False
#
#       x gk location  y gk location  ...    player name            Team Name  \
# 8461            NaN            NaN  ...  Caroline Weir  Manchester City WFC
#
#       official xg  Pass id Pass Type game_id  season_id  \
# 8461     0.084921  No Pass      None   19764  2018/2019
#
#      distance_from_goalpost_a distance_from_goalpost_b shot_angle
# 8461                27.784888                24.738634       16.2
#
# [1 rows x 24 columns]

# %%
df=df.dropna(how='any',subset=['x gk location'])

# %%
df.isna().sum()
# Out:
# shot id                           0
# play pattern                      0
# x location shot                   0
# y location shot                   0
# duration                          0
# outcome                           0
# technique used                    0
# first time                        0
# x gk location                     0
# y gk location                     0
# body part                         0
# type of shot                      0
# Number of opponents in 5 yards    0
# Players between goal              0
# player name                       0
# Team Name                         0
# official xg                       0
# Pass id                           0
# Pass Type                         0
# game_id                           0
# season_id                         0
# distance_from_goalpost_a          0
# distance_from_goalpost_b          0
# shot_angle                        0
# dtype: int64

# %%
df.to_pickle('./womens_data.pkl')

# %%
football_df = pd.concat([df, laliga_shots], ignore_index=True)

# %%
football_df
# Out:
#                                     shot id    play pattern  x location shot  \
# 0      56deeffa-ff55-429e-91df-41f237a3ebac    Regular Play            103.7
# 1      00d9c066-1078-4e1c-8c7f-2ca299e3a5f0  From Free Kick            107.4
# 2      48706448-928f-4721-96ec-2b813f448937    Regular Play            108.5
# 3      718f8a06-078c-489e-9423-63d414be5e43   From Throw In            106.0
# 4      e1b29724-4861-4d12-9a51-ac6635e97438     From Corner            112.4
# ...                                     ...             ...              ...
# 23512  4468faac-ae6a-4637-928b-fc7dd448411b  From Free Kick             91.1
# 23513  5f613006-c00e-4581-882c-a7a81978ebf0   From Throw In            103.7
# 23514  717c9351-6eff-4f71-969a-e25bab5bfcb6   From Throw In            107.9
# 23515  0c914938-af14-479e-8043-8e4bfdfd474d   From Throw In            117.8
# 23516  d9533117-d840-4973-91cd-9472a76d705e  From Free Kick            108.5
#
#        y location shot  duration outcome technique used  first time  \
# 0                 46.3  0.909600   Saved         Normal        True
# 1                 37.4  1.033500    Goal         Normal       False
# 2                 48.1  1.391602   Off T         Normal       False
# 3                 43.7  1.154700   Saved         Normal       False
# 4                 42.9  0.907511   Off T         Normal       False
# ...                ...       ...     ...            ...         ...
# 23512             47.1  1.622413    Post         Normal       False
# 23513             33.6  1.070861   Off T    Half Volley       False
# 23514             37.0  0.701300   Saved         Volley        True
# 23515             43.9  1.256200    Post         Normal       False
# 23516             45.6  1.316500   Off T         Normal       False
#
#        x gk location  y gk location  ...  \
# 0              116.0           43.0  ...
# 1              118.3           39.9  ...
# 2              118.9           42.8  ...
# 3              118.9           42.1  ...
# 4              119.3           40.7  ...
# ...              ...            ...  ...
# 23512          118.4           40.8  ...
# 23513          119.5           39.8  ...
# 23514          119.2           39.6  ...
# 23515          118.9           43.3  ...
# 23516          119.6           41.4  ...
#
#                                 player name          Team Name  official xg  \
# 0                         Samantha May Kerr  Australia Women's     0.174474
# 1                         Samantha May Kerr  Australia Women's     0.028797
# 2                         Samantha May Kerr  Australia Women's     0.027564
# 3                         Samantha May Kerr  Australia Women's     0.025206
# 4                         Samantha May Kerr  Australia Women's     0.065884
# ...                                     ...                ...          ...
# 23512              Giovanni van Bronckhorst          Barcelona     0.049559
# 23513             Ferrán Corominas Telechea           Espanyol     0.057103
# 23514  Mauricio Roberto Pochettino Trossero           Espanyol     0.113389
# 23515             Ferrán Corominas Telechea           Espanyol     0.415576
# 23516  Mauricio Roberto Pochettino Trossero           Espanyol     0.051609
#
#                                     Pass id    Pass Type game_id  season_id  \
# 0      448cb3aa-ee0b-4829-a7d4-bdef6dfda5bd  Ground Pass   68311       2019
# 1      f5d55ee4-2db3-4604-b9fa-8bd0645fdc4b    High Pass   68311       2019
# 2      13eaef4e-1393-4b99-b94d-d60c35070713    High Pass   68311       2019
# 3      be417f5e-798b-4dd0-a651-4b7a9d2e3564    High Pass   68311       2019
# 4      ef4852cb-22f5-4afe-8355-5ec0752f9adb    High Pass   68311       2019
# ...                                     ...          ...     ...        ...
# 23512                               No Pass         None   68353  2004/2005
# 23513                               No Pass         None   68353  2004/2005
# 23514  dbaca88f-32d3-4abe-a37d-4fceb67a4302     Low Pass   68353  2004/2005
# 23515                               No Pass         None   68353  2004/2005
# 23516  f2137b0f-01b5-4311-8eea-955918e63892    High Pass   68353  2004/2005
#
#       distance_from_goalpost_a distance_from_goalpost_b shot_angle
# 0                    19.281597                16.461470       24.3
# 1                    12.677539                14.223924       34.0
# 2                    16.693112                12.209013       26.8
# 3                    15.977797                14.003214       30.0
# 4                    10.264989                 7.679193       50.5
# ...                        ...                      ...        ...
# 23512                30.958359                29.065787       14.9
# 23513                16.475740                19.335201       24.2
# 23514                12.141252                13.978913       34.8
# 23515                 8.200610                 2.202272       77.0
# 23516                14.980320                11.610771       31.9
#
# [23517 rows x 24 columns]

# %%
football_df.isna().sum()
# Out:
# shot id                           0
# play pattern                      0
# x location shot                   0
# y location shot                   0
# duration                          0
# outcome                           0
# technique used                    0
# first time                        0
# x gk location                     1
# y gk location                     1
# body part                         0
# type of shot                      0
# Number of opponents in 5 yards    0
# Players between goal              0
# player name                       0
# Team Name                         0
# official xg                       0
# Pass id                           0
# Pass Type                         0
# game_id                           0
# season_id                         0
# distance_from_goalpost_a          0
# distance_from_goalpost_b          0
# shot_angle                        3
# dtype: int64

# %% [markdown]
# There are some values missing in the goal keeper location and the shot angle sections.

# %%
football_df[football_df['shot_angle'].isna()]
# Out:
#                                     shot id    play pattern  x location shot  \
# 2820   43fc3329-220a-4141-a948-e79082759be7     From Corner            120.0
# 6667   438b2bc2-8f54-4c4d-8971-7e6efaa96e5a    Regular Play            120.0
# 15799  7540f106-869b-4cb8-8a6b-d1db41f7b759  From Free Kick            120.0
#
#        y location shot  duration outcome technique used  first time  \
# 2820              34.7  0.899775   Off T         Normal       False
# 6667              30.6  0.276294   Saved         Normal       False
# 15799             43.7  0.300900    Goal         Normal        True
#
#        x gk location  y gk location  ...               player name  \
# 2820           119.3           37.4  ...       Samantha June Mewis
# 6667           119.6           36.3  ...              Lauren James
# 15799          113.2           33.3  ...  Luis Alberto Suárez Díaz
#
#                  Team Name  official xg                               Pass id  \
# 2820   Manchester City WFC     0.139676  c2446bcc-6442-481d-a360-49f862953de9
# 6667     Manchester United     0.067796                               No Pass
# 15799            Barcelona     0.898411                               No Pass
#
#        Pass Type  game_id  season_id distance_from_goalpost_a  \
# 2820   High Pass  3775624  2020/2021                      1.3
# 6667        None  2275139  2019/2020                      5.4
# 15799       None   266254  2015/2016                      7.7
#
#       distance_from_goalpost_b shot_angle
# 2820                       9.3        NaN
# 6667                      13.4        NaN
# 15799                      0.3        NaN
#
# [3 rows x 24 columns]

# %% [markdown]
# It seems like the goal was shot from an extreme angle in these situations. We will simply fill 0 values.

# %%
football_df['shot_angle']=football_df['shot_angle'].fillna(0)

# %%
football_df[football_df['x gk location'].isna()]
# Out:
#                                    shot id    play pattern  x location shot  \
# 8461  9c60dc1c-16e8-40d0-9522-665e7993c188  From Free Kick             96.0
#
#       y location shot  duration  outcome technique used  first time  \
# 8461             50.0    0.6414  Blocked         Normal       False
#
#       x gk location  y gk location  ...    player name            Team Name  \
# 8461            NaN            NaN  ...  Caroline Weir  Manchester City WFC
#
#       official xg  Pass id Pass Type game_id  season_id  \
# 8461     0.084921  No Pass      None   19764  2018/2019
#
#      distance_from_goalpost_a distance_from_goalpost_b shot_angle
# 8461                27.784888                24.738634       16.2
#
# [1 rows x 24 columns]

# %% [markdown]
# Due to the lack of data we will have to drop this particular entry.

# %%
football_df=football_df.dropna(how='any',subset=['x gk location'])

# %%
football_df.isna().sum()
# Out:
# shot id                           0
# play pattern                      0
# x location shot                   0
# y location shot                   0
# duration                          0
# outcome                           0
# technique used                    0
# first time                        0
# x gk location                     0
# y gk location                     0
# body part                         0
# type of shot                      0
# Number of opponents in 5 yards    0
# Players between goal              0
# player name                       0
# Team Name                         0
# official xg                       0
# Pass id                           0
# Pass Type                         0
# game_id                           0
# season_id                         0
# distance_from_goalpost_a          0
# distance_from_goalpost_b          0
# shot_angle                        0
# dtype: int64

# %%
football_df.to_pickle('./final_data.pkl')
